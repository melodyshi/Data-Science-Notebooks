# %%
import requests
import pandas as pd

# %%
def yelp_gym(term="gym",location="Downtown, New York"):
    search_url = 'https://api.yelp.com/v3/businesses/search'
    parameters = {
        'term' : term,
        'location' : location
    }
    header = {
        'Authorization': 'Bearer p7FmVUMhc0KFHDKGEY8FOKit1nS2Wv1PoUWy0UrDAKKrIO07eAJCXu_wJDbJLMMrot5epyl7isB7eQZ5-vVjcDVmjaDXP_OGS_Y7cWwG9-ApypPUJpfFjPG5N1nUW3Yx'
    }
    response = requests.get(search_url,params=parameters,headers=header).json()
    return response

# %%
response = yelp_gym(term="uxf zone")

# %%
response
# Out:
# {'businesses': [{'alias': 'new-york-sports-clubs-new-york-57',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7116578, 'longitude': -74.008679},
#    'display_phone': '(212) 791-9555',
#    'distance': 1528.244881463889,
#    'id': 'ckrXklnygfn4w8shgoToog',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ayjAcHEH_1371XNaZnKSnA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '217 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['217 Broadway', 'New York, NY 10007'],
#     'state': 'NY',
#     'zip_code': '10007'},
#    'name': 'New York Sports Clubs',
#    'phone': '+12127919555',
#    'rating': 2.5,
#    'review_count': 79,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-57?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-new-york-77',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7845765, 'longitude': -73.9799565},
#    'display_phone': '(212) 873-1500',
#    'distance': 7136.572997009254,
#    'id': '3m5kIjfK5D2vDyixfawrCQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DMQKA7yYV89P8SAXrazVMg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '248 W 80th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['248 W 80th St', 'New York, NY 10024'],
#     'state': 'NY',
#     'zip_code': '10024'},
#    'name': 'New York Sports Clubs',
#    'phone': '+12128731500',
#    'rating': 2.0,
#    'review_count': 76,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-77?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-new-york-62',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7275513, 'longitude': -73.9959834},
#    'display_phone': '(212) 780-7407',
#    'distance': 673.918452418067,
#    'id': 'fsQ1OrvOckKOImpVn7ELrQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CmNKKsTeN235nq0xfM0_LA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '232 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['232 Mercer St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'New York Sports Clubs',
#    'phone': '+12127807407',
#    'rating': 2.5,
#    'review_count': 119,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-62?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-new-york-76',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.777669, 'longitude': -73.976773},
#    'display_phone': '(212) 496-6300',
#    'distance': 6453.503681353947,
#    'id': 'ABN8Noqe2ghG_2Vy-_6iVg',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8pZGFXEw6UZpqpjh9cb2gg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '23 W 73rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['23 W 73rd St', 'New York, NY 10023'],
#     'state': 'NY',
#     'zip_code': '10023'},
#    'name': 'New York Sports Clubs',
#    'phone': '+12124966300',
#    'rating': 2.5,
#    'review_count': 83,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-76?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-new-york-61',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7821171, 'longitude': -73.9510046},
#    'display_phone': '(212) 987-7200',
#    'distance': 7734.181839825585,
#    'id': 'ycqHtU6q9iuYrHBSAzSkRQ',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UQSgBFSbzQr402igiInyfw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1637 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['1637 3rd Ave', 'New York, NY 10128'],
#     'state': 'NY',
#     'zip_code': '10128'},
#    'name': 'New York Sports Clubs',
#    'phone': '+12129877200',
#    'rating': 2.0,
#    'review_count': 200,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-61?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-new-york-50',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7710330509793,
#     'longitude': -73.955099847517},
#    'display_phone': '(212) 288-5700',
#    'distance': 6498.060204716792,
#    'id': 'fW-xgAHNzXOhMu_2K4LqCQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/o4adQvH_ylmuwxTLQeFHWg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '349 E 76th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['349 E 76th St', 'New York, NY 10021'],
#     'state': 'NY',
#     'zip_code': '10021'},
#    'name': 'New York Sports Clubs',
#    'phone': '+12122885700',
#    'rating': 2.0,
#    'review_count': 167,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-new-york-50?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-brooklyn-9',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.6932804, 'longitude': -73.9911435},
#    'display_phone': '(718) 246-0600',
#    'distance': 3163.5367649289133,
#    'id': 'JN0iqiplT5JqDbo_RvvSeA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zx0zX4lShiSadnJX0sAwAw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '179 Remsen St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['179 Remsen St', 'Brooklyn, NY 11201'],
#     'state': 'NY',
#     'zip_code': '11201'},
#    'name': 'New York Sports Clubs',
#    'phone': '+17182460600',
#    'rating': 2.0,
#    'review_count': 139,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-brooklyn-9?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-astoria',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7643818, 'longitude': -73.9155212},
#    'display_phone': '(718) 932-1400',
#    'distance': 8290.119993100689,
#    'id': 'HN1CZrV0zpg5BD2PkSSC6g',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GQzOPLDCtBFqVjB25G1UDw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '38-11 30th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'country': 'US',
#     'display_address': ['38-11 30th Ave', 'Astoria, NY 11103'],
#     'state': 'NY',
#     'zip_code': '11103'},
#    'name': 'New York Sports Clubs',
#    'phone': '+17189321400',
#    'rating': 2.5,
#    'review_count': 218,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-astoria?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'},
#   {'alias': 'new-york-sports-clubs-sunnyside',
#    'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#     {'alias': 'healthtrainers', 'title': 'Trainers'}],
#    'coordinates': {'latitude': 40.7445625095695,
#     'longitude': -73.9256883450253},
#    'display_phone': '(718) 361-2254',
#    'distance': 6456.754298623609,
#    'id': 'YH5btkUScbAWVU0Uye-x2A',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h3NHfUeiChJ_RQ7A1_14yg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '39-01 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'country': 'US',
#     'display_address': ['39-01 Queens Blvd', 'Sunnyside, NY 11104'],
#     'state': 'NY',
#     'zip_code': '11104'},
#    'name': 'New York Sports Clubs',
#    'phone': '+17183612254',
#    'rating': 2.5,
#    'review_count': 121,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/new-york-sports-clubs-sunnyside?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=G0iO-5RiEaS5hJIylyCdCQ'}],
#  'region': {'center': {'latitude': 40.72149063211986,
#    'longitude': -73.99600982666016}},
#  'total': 9}

# %%
def fmt(name):
    query_tplt = "{} = business['{}']"
    print("'{}' = {},".format(name,name))
    return query_tplt.format(name,name)

# %%
fmt('distance')
# Out:
# 'distance' = distance,
# "distance = business['distance']"

# %%
entry_list = []
for business in response['businesses']:
    business_id = business['id']
    name = business['name']
    image_url = business['image_url']
    is_closed = business['is_closed']
    url = business['url']
    review_count = business['review_count']
    rating = business['rating']
    latitude = business['coordinates']['latitude']
    longitude = business['coordinates']['longitude']
    address_1 = business['location']['address1']
    address_2 = business['location']['address2']
    address_3 = business['location']['address3']
    city = business['location']['city']
    zip_code = business['location']['zip_code']
    country = business['location']['country']
    state = business['location']['state']
    phone = business['phone']
    distance = business['distance']
    
    entry = {
        'business_id' : business_id,
        'name' : name,
        'image_url' : image_url,
        'is_closed' : is_closed,
        'url' : url,
        'review_count' : review_count,
        'rating' : rating,
        'latitude' : latitude,
        'longitude' : longitude,
        'address_1' : address_1,
        'address_2' : address_2,
        'address_3' : address_3,
        'city' : city,
        'zip_code' : zip_code,
        'country' : country,
        'state' : state,
        'phone' : phone,
        'distance' : distance
    }
    entry_list.append(entry)
pd.DataFrame(entry_list)
# Out:
#             address_1 address_2 address_3             business_id       city  \
# 0     100 Delancey St                      93QbRHjAup3Eq2vGipgi0Q   New York
# 1     227 Mulberry St                None  DzlmPGxCg3wRyGJiNoSFow   New York
# 2         137 5th Ave      #10r      None  syK3qJ-zv9AKf6v2meLCQA   New York
# 3       100 Morton St                      SU5xh7FWOHyptU6DacPyOA   New York
# 4   600 Washington St      None            vmhevPOT6au2sRnjdNbWBQ   New York
# 5       255 Centre St      Fl 2            dfyEtaRU6ORBoojAaWzVxg   New York
# 6        285 Grand St      None            UR4cr_OXx5wl-I6hNqr_SA   New York
# 7       440 W 57th St                      7Z5rID_xwYPRO7m7NjiVLw   New York
# 8       10 Hanover Sq                      ypeRKaFOXoO8QuzAmmoPVg   New York
# 9        140 Broadway                None  Xpi_GKjAuZsJbZfP4S9Fmw   New York
# 10      287 E 10th St      None            PmcXx7AX2F9ifD1ndUCD9A  Manhattan
# 11   60 Chelsea Piers                      YMceMR-Hk_Vq5vbUGoetrQ   New York
# 12       69 Prince St      None            RcICYboQMVOs9B3hONESgg   New York
# 14      False  40.747950 -74.000630        CKO Kickboxing Chelsea
# 15      False  40.720841 -73.996429             SoHo Strength Lab
# 16      False  40.727300 -73.991748       Crunch Fitness - Bowery
# 17      False  40.718799 -73.991874                       ConBody
# 18      False  40.719620 -73.993910           Mark Fisher Fitness
# 19      False  40.709615 -74.009577                    Just Train
#
#            phone  rating  review_count state  \
# 0   +12122609222     4.5           122    NY
# 1   +16466784723     4.5            20    NY
# 2   +18458533166     5.0            14    NY
# 3   +18319173032     5.0            10    NY
# 4   +16464908500     4.5            31    NY
# 5   +12129257177     4.5            12    NY
# 6   +15167255032     5.0            36    NY
# 7   +12129574781     5.0            27    NY
# 8   +12127777702     4.0           102    NY
# 9   +12123085824     4.0            19    NY
# 10  +13475263965     5.0             5    NY
# 11  +12123366000     4.5           151    NY
# 12  +12123344631     3.5           138    NY
# 13  +12122800689     5.0            16    NY
# 14  +19173882664     5.0             3    NY
# 15  +12122268682     5.0            12    NY
# 16  +12126140120     3.5           111    NY
# 17  +13472510423     5.0            87    NY
# 18  +12123560020     5.0            18    NY
# 19  +12129207739     5.0            37    NY
#
#                                                   url zip_code
# 0   https://www.yelp.com/biz/ludlow-fitness-new-yo...    10002
# 1   https://www.yelp.com/biz/gym-nyc-new-york?adju...    10012
# 2   https://www.yelp.com/biz/encore-fitness-new-yo...    10010
# 3   https://www.yelp.com/biz/gores-core-fitness-ne...    10014
# 4   https://www.yelp.com/biz/gotham-gym-new-york?a...    10014
# 5   https://www.yelp.com/biz/cordell-fitness-inc-n...    10013
# 6   https://www.yelp.com/biz/bowery-crossfit-new-y...    10002
# 7   https://www.yelp.com/biz/new-york-underground-...    10019
# 8   https://www.yelp.com/biz/completebody-new-york...    10005
# 9   https://www.yelp.com/biz/crunch-fidi-new-york?...    10005
# 10  https://www.yelp.com/biz/health-and-fitness-an...    10009
# 11  https://www.yelp.com/biz/chelsea-piers-fitness...    10011
# 12  https://www.yelp.com/biz/equinox-soho-new-york...    10012
# 13  https://www.yelp.com/biz/x-93-fitness-new-york...    10025
# 14  https://www.yelp.com/biz/cko-kickboxing-chelse...    10001
# 15  https://www.yelp.com/biz/soho-strength-lab-new...    10012
# 16  https://www.yelp.com/biz/crunch-bowery-new-yor...    10003
# 17  https://www.yelp.com/biz/conbody-new-york?adju...    10002
# 18  https://www.yelp.com/biz/mark-fisher-fitness-n...    10002
# 19  https://www.yelp.com/biz/just-train-new-york?a...    10038

# %%
businessID = response['businesses'][0]['id']

# %%
info_url = 'https://api.yelp.com/v3/businesses/{}'.format(businessID)
requests.get(info_url,headers = header).json()
# Out:
# {'alias': 'cafe-sushi-cambridge',
#  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#   {'alias': 'japanese', 'title': 'Japanese'}],
#  'coordinates': {'latitude': 42.37077, 'longitude': -71.11355},
#  'display_phone': '(617) 492-0434',
#  'hours': [{'hours_type': 'REGULAR',
#    'is_open_now': False,
#    'open': [{'day': 0, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#     {'day': 0, 'end': '2200', 'is_overnight': False, 'start': '1730'},
#     {'day': 1, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#     {'day': 1, 'end': '2200', 'is_overnight': False, 'start': '1730'},
#     {'day': 2, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#     {'day': 2, 'end': '2200', 'is_overnight': False, 'start': '1730'},
#     {'day': 3, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#     {'day': 3, 'end': '2200', 'is_overnight': False, 'start': '1730'},
#     {'day': 4, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#     {'day': 4, 'end': '2230', 'is_overnight': False, 'start': '1730'},
#     {'day': 5, 'end': '1430', 'is_overnight': False, 'start': '1200'},
#     {'day': 5, 'end': '2230', 'is_overnight': False, 'start': '1730'},
#     {'day': 6, 'end': '2200', 'is_overnight': False, 'start': '1730'}]}],
#  'id': 'SSmHkP0tZ4TKn_YUOEkVUg',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e2qCbCkkpXHw07wlKjn7cQ/o.jpg',
#  'is_claimed': True,
#  'is_closed': False,
#  'location': {'address1': '1105 Massachusetts Ave',
#   'address2': '',
#   'address3': '',
#   'city': 'Cambridge',
#   'country': 'US',
#   'cross_streets': '',
#   'display_address': ['1105 Massachusetts Ave', 'Cambridge, MA 02138'],
#   'state': 'MA',
#   'zip_code': '02138'},
#  'name': 'Cafe Sushi',
#  'phone': '+16174920434',
#  'photos': ['https://s3-media3.fl.yelpcdn.com/bphoto/e2qCbCkkpXHw07wlKjn7cQ/o.jpg',
#   'https://s3-media3.fl.yelpcdn.com/bphoto/4ciEUpmOOIC96uTun2AJCA/o.jpg',
#   'https://s3-media2.fl.yelpcdn.com/bphoto/bkqv2lHoXzw3O6AwI8ex3w/o.jpg'],
#  'price': '$$',
#  'rating': 4.0,
#  'review_count': 620,
#  'transactions': [],
#  'url': 'https://www.yelp.com/biz/cafe-sushi-cambridge?adjust_creative=G0iO-5RiEaS5hJIylyCdCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_lookup&utm_source=G0iO-5RiEaS5hJIylyCdCQ'}

# %%
purpose = "pur"
where = "whe"
limit = 5

query_template = '''
SELECT Conditions, Primary_Purpose
FROM clinical_trial
WHERE Primary_Purpose = "{}"
  AND Interventions Methods IN {}
ORDER BY Conditions DESC
LIMIT {};
'''

query = query_template.format(purpose,where,limit)
query
# Out:
# '\nSELECT Conditions, Primary_Purpose\nFROM clinical_trial\nWHERE Primary_Purpose = "pur"\n  AND Interventions Methods IN whe\nORDER BY Conditions DESC\nLIMIT 5;\n'

# %%
import urllib2

url = 'http://www.oldbaileyonline.org/print.jsp?div=t17800628-33'

response = urllib2.urlopen(url)
webContent = response.read()

f = open('obo-t17800628-33.html', 'w')
f.write(webContent)
f.close()
# Out:
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-6-e7077f3d8003> in <module>()
# ----> 1 import urllib2
#       2
#       3 url = 'http://www.oldbaileyonline.org/print.jsp?div=t17800628-33'
#       4
#       5 response = urllib2.urlopen(url)
#
# ModuleNotFoundError: No module named 'urllib2'

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Nov 22 17:32:36 2018

@author: Melody Shi
"""

import requests
import pandas as pd

def yelp_gym(term="gym",location="Downtown, New York"):
    """
        Makes requests to get response from Yelp API. Account limit: 1000 calls per day.
        
        Parameters
        ----------
        term: str
            search query, defaults to "gym"
        location: str
            the location query, defaults to "Downtown, New York"
            
        Returns
        -------
        a response directly returned by Yelp API containing structured data
          
    """
    search_url = 'https://api.yelp.com/v3/businesses/search'
    parameters = {
        'term' : term,
        'location' : location
    }
    header = {
        'Authorization': 'Bearer p7FmVUMhc0KFHDKGEY8FOKit1nS2Wv1PoUWy0UrDAKKrIO07eAJCXu_wJDbJLMMrot5epyl7isB7eQZ5-vVjcDVmjaDXP_OGS_Y7cWwG9-ApypPUJpfFjPG5N1nUW3Yx'
    }
    response = requests.get(search_url,params=parameters,headers=header).json()
    return response

def gym(term,location):
    """
        Makes requests to get response from Yelp API, extracts information and builds
        a dataframe
        
        Parameters
        ----------
        term: str
            search query
        location: str
            the location query
            
        Returns
        -------
        a DataFrame object that contains information including business name, address, rating,
        contact information, etc.
          
    """
    response = yelp_gym(term=term,location=location)
    entry_list = []
    for business in response['businesses']:
        business_id = business['id']
        name = business['name']
        image_url = business['image_url']
        is_closed = business['is_closed']
        url = business['url']
        review_count = business['review_count']
        rating = business['rating']
        latitude = business['coordinates']['latitude']
        longitude = business['coordinates']['longitude']
        address_1 = business['location']['address1']
        address_2 = business['location']['address2']
        address_3 = business['location']['address3']
        city = business['location']['city']
        zip_code = business['location']['zip_code']
        country = business['location']['country']
        state = business['location']['state']
        phone = business['phone']
        distance = business['distance']
        
        entry = {
            'business_id' : business_id,
            'name' : name,
            'image_url' : image_url,
            'is_closed' : is_closed,
            'url' : url,
            'review_count' : review_count,
            'rating' : rating,
            'latitude' : latitude,
            'longitude' : longitude,
            'address_1' : address_1,
            'address_2' : address_2,
            'address_3' : address_3,
            'city' : city,
            'zip_code' : zip_code,
            'country' : country,
            'state' : state,
            'phone' : phone,
            'distance' : distance
        }
        entry_list.append(entry)
    return pd.DataFrame(entry_list) 

# main function for testing purpose
if __name__ == "__main__":
    df = gym("gym","23rd & Park, New York, NY")

# %%
df_sorted = df.sort_values(by="distance")
df_sorted
# Out:
#            address_1 address_2 address_3             business_id      city  \
# 5        270 8th Ave                      LN1itZNPsylqInDsLG4M_g  New York
# 0     308 Eighth Ave                      sGyIlg7CwXS92KfgcAQ0uA  New York
# 6      215 W 23rd St                      pYp5IoSC9HuaZTAPsqyOFA  New York
# 2      250 W 26th St      Fl 4            leVqeIg0IAqHWij7oM3__w  New York
# 9        249 9th Ave                None  FuPtJE_jC0u3o9g-O89u6A  New York
# 3      220 W 19th St      None      None  CiVkmHpcGhGMxElD70_6aA  New York
# 19     158 W 27th St                      AUzN5ljn_A4JGckDCjT4MA  New York
# 1      257 W 17th St      None            O6ApQ0csoQqG6y3rW2zBcg  New York
# 18     143 W 19th St                      bE3UNyAzH99CVQbkm8ooWA  New York
# 13      60 W 23rd St                      JaMPhgH-Mk7Uln1-nJ1eiA  New York
# 7        656 6th Ave      None            cN-j9UNXsgZ9N153CJDmgg  New York
# 16     127 W 30th St                      d39o5ud7fwRbk5voplSi4A  New York
# 14      100 10th Ave                      K_v5t4VQHcZLl4cxXieDig  New York
# 11       555 6th Ave                      VI-1gfoAOp3TmQLrwwzizw  New York
# 6                  Crunch Fitness - 23rd Street  +12123700977     3.5
# 2                                     Studio 26  +16467558125     4.5
# 9                        CKO Kickboxing Chelsea  +19173882664     5.0
# 3                  Crunch Fitness - 19th Street  +12123700998     4.0
# 19        Planet Fitness - Manhattan - 27th St.  +12122682501     3.0
# 1                                Brick New York  +16466924005     4.5
# 18                                The Works NYC  +16467558919     5.0
# 13               New York Health & Racquet Club  +12129892300     3.5
# 7                             Limelight Fitness  +16469645741     4.0
# 16                 Blink Fitness - Penn Station  +16467952795     3.0
# 14                             Equinox Highline  +12123670863     3.5
# 11                                     NYSC Lab  +19173825573     4.5
# 15               Rich Barretta Private Training  +12126271496     5.0
# 8                                      Liftonic  +12122200529     5.0
# 4                         Chelsea Piers Fitness  +12123366000     4.5
# 12  24 Hour Fitness - Madison Square Park Ultra  +12122711002     3.0
# 17                       CLAY Health Club + Spa  +12122069200     4.0
# 10                               Encore Fitness  +18458533166     5.0
#
#     review_count state                                                url  \
# 5             92    NY  https://www.yelp.com/biz/new-york-sports-clubs...
# 0            101    NY  https://www.yelp.com/biz/blink-fitness-chelsea...
# 6             59    NY  https://www.yelp.com/biz/crunch-fitness-23rd-s...
# 2             20    NY  https://www.yelp.com/biz/studio-26-new-york?ad...
# 9              1    NY  https://www.yelp.com/biz/cko-kickboxing-chelse...
# 3            107    NY  https://www.yelp.com/biz/crunch-fitness-19th-s...
# 19           126    NY  https://www.yelp.com/biz/planet-fitness-manhat...
# 1             47    NY  https://www.yelp.com/biz/brick-new-york-new-yo...
# 18            20    NY  https://www.yelp.com/biz/the-works-nyc-new-yor...
# 13           146    NY  https://www.yelp.com/biz/new-york-health-and-r...
# 7             14    NY  https://www.yelp.com/biz/limelight-fitness-new...
# 16            88    NY  https://www.yelp.com/biz/blink-fitness-penn-st...
# 14            74    NY  https://www.yelp.com/biz/equinox-highline-new-...
# 11           106    NY  https://www.yelp.com/biz/nysc-lab-new-york?adj...
# 15            66    NY  https://www.yelp.com/biz/rich-barretta-private...
# 8             81    NY  https://www.yelp.com/biz/liftonic-new-york?adj...
# 4            151    NY  https://www.yelp.com/biz/chelsea-piers-fitness...
# 12           205    NY  https://www.yelp.com/biz/24-hour-fitness-madis...
# 17            98    NY  https://www.yelp.com/biz/clay-health-club-spa-...
# 10            11    NY  https://www.yelp.com/biz/encore-fitness-new-yo...
#
#    zip_code
# 5     10011
# 0     11103
# 6     10011
# 2     10001
# 9     10001
# 3     10011
# 19    10001
# 1     10011
# 18    10011
# 13    10010
# 7     10010
# 16    10001
# 14    10011
# 11    10001
# 15    10010
# 8     10014
# 4     10011
# 12    10010
# 17    10011
# 10    10010

# %%
for index,row in df_sorted.iterrows():
    print(row["distance"])
# Out:
# 66.67291835186101
# 199.93439300333944
# 213.6286025934755
# 245.74286919125788
# 358.63854227732656
# 368.08545710254316
# 438.7159316251158
# 446.2384203921929
# 475.5681299443648
# 610.5139763808601
# 620.5380550163592
# 705.1429943915331
# 712.1335363019224
# 763.096342935451
# 814.125980028477
# 843.6708801706156
# 918.6543789827052
# 938.8281700812412
# 996.274185338763
# 1280.9149786058615
