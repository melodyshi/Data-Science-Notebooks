# %%
import pandas as pd
import pickle

# %%
import requests
    

def call_google_maps(address):
    """
        Makes requests to get response from Google Maps Geocoding API.
        Account limit: Unlimited until google credits run out.
        
        Parameters:
            address: str
            
        Returns:
            a response from Google Maps Geocoding API containing structured 
            data
        
    """
    
    google_maps_url = 'https://maps.googleapis.com/maps/api/geocode/json' 
    api_key = 'AIzaSyD9I99AhO7IUXDoXe6z_zZWW6hiW2kGL5o'
    params = {
        'address': address,
        'key' : api_key,
        'region': 'usa',
    }
    req = requests.get(google_maps_url, params=params)
    
    results = req.json()
    
    if 'results' in results and len(results['results'])>0:
        result = results['results'][0]
        return result
    else:
        return None
    
def get_lat_lon(address):
    """
        Calls the google maps function to get structured data and then we 
        generate the Latitude and Longitude of the address
        
        Parameters:
            address: str
                search query
        Returns:
            The Latitude and Longitude given by the Geocoding API.
            If there is no Latitude or Longitude it defaults to New York's 
            Latitude and Longitude
            
    """
    google_result = call_google_maps(address)
    try:
        coordinates = google_result['geometry']['location']
        lat = coordinates['lat']
        lon = coordinates['lng']
    except:
        lat = "40.7128"
        lon = "74.0060"
    return lat,lon

def get_postal_code(address):
    """
        Calls the google maps function to get structured data and then we 
        generate the postal code of the address
        
        Parameters:
            address: str
                search query
        Returns:
            The postal code given by the Geocoding API.
            If there is no postal code it defaults the postal code to 0000000
    """
    address_new = "New York Sports Club"
    address_new += address
    address_new += ", New York"
    google_result = call_google_maps(address_new)
    try:
        long_name = google_result['address_components'][-1:][0]
        if long_name["types"][0] != "postal_code":
            long_name = google_result['address_components'][-2:-1][0]
        postal_code = long_name.get('long_name')
    except:
        postal_code = "00000"
    return postal_code

# %%
get_postal_code("New York Sports Club, Dobbs Ferry, New York")
# Out:
# {'address_components': [{'long_name': '50', 'short_name': '50', 'types': ['street_number']}, {'long_name': 'Hamilton Street', 'short_name': 'Hamilton St', 'types': ['route']}, {'long_name': 'Dobbs Ferry', 'short_name': 'Dobbs Ferry', 'types': ['locality', 'political']}, {'long_name': 'Greenburgh', 'short_name': 'Greenburgh', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'Westchester County', 'short_name': 'Westchester County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10522', 'short_name': '10522', 'types': ['postal_code']}], 'formatted_address': '50 Hamilton St, Dobbs Ferry, NY 10522, USA', 'geometry': {'location': {'lat': 41.00329, 'lng': -73.8568971}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 41.0046389802915, 'lng': -73.8555481197085}, 'southwest': {'lat': 41.0019410197085, 'lng': -73.85824608029151}}}, 'place_id': 'ChIJ-z1BK7vswokRXyEUFohcNTc', 'plus_code': {'compound_code': '243V+86 Dobbs Ferry, Greenburgh, NY, United States', 'global_code': '87H8243V+86'}, 'types': ['establishment', 'gym', 'health', 'point_of_interest']}
# '10522'

# %%
with open("parks.pk","rb") as f:
    park = pickle.load(f)
with open("soulcycle.pk","rb") as f:
    cycle = pickle.load(f)
with open("nysc.pk","rb") as f:
    nysc = pickle.load(f)

# %%
with open("soulcycle.pk","rb") as f:
    cycle = pickle.load(f)

# %%
with open("nysc.pk","rb") as f:
    nysc = pickle.load(f)

# %%
park['url'] = "https://www.nycgovparks.org/programs/recreation/shape-up-nyc?fbclid=IwAR2fu7flf3TdXJicDvHYsTDBBlI054ECUvKGhAjR6nqKj4CQbiDvURdegLk"

# %%
park.head(10)
# Out:
#                     address                        category  \
# 0     286 East 156th Street                  Aerobic Dance
# 1            1257 Ogden Ave  Bilingual Belly Dance Fitness
# 2     234 East 149th Street        Bilingual Dance Fitness
# 3    450 Saint Ann's Avenue                Bilingual Zumba
# 4           595 Trinity Ave                Bilingual Zumba
# 5      85 East 165th Street              Body Conditioning
# 6      85 East 165th Street           Body Conditioning II
# 7           1501 Jerome Ave                 Body Sculpting
# 8  3225 Reservoir Oval East                       Bodywork
# 9     1550 Lafayette Avenue                          Bokwa
#
#                              center_name        day    end_time  start_time
# 0              Bronxworks Classic Center   Thursday   8:00 p.m.   7:00 p.m.
# 1                                P.S. 11  Wednesday  10:30 a.m.   9:00 a.m.
# 2                       Lincoln Hospital   Thursday   7:00 p.m.   6:00 p.m.
# 3           St. Mary’s Recreation Center   Thursday   8:00 p.m.   7:00 p.m.
# 4            St. Mary's Community Center  Wednesday   8:00 p.m.   7:00 p.m.
# 5              Church of God of Prophecy  Wednesday   7:00 p.m.   6:00 p.m.
# 6              Church of God of Prophecy   Saturday  11:30 a.m.  10:30 a.m.
# 7        New Settlement Community Center  Wednesday  11:00 a.m.  10:00 a.m.
# 8  Williamsbridge Oval Recreation Center    Tuesday   7:30 p.m.   6:30 p.m.
# 9             Soundview Park Field House     Sunday  12:00 p.m.  11:00 a.m.

# %%
park["length"] = park.apply(get_length,axis=1)

# %%
park["zip_code"] = park.address.apply(get_postal_code)
# Out:
# {'address_components': [{'long_name': '286', 'short_name': '286', 'types': ['street_number']}, {'long_name': 'East 156th Street', 'short_name': 'E 156th St', 'types': ['route']}, {'long_name': 'Melrose', 'short_name': 'Melrose', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}], 'formatted_address': '286 E 156th St, Bronx, NY 10451, USA', 'geometry': {'location': {'lat': 40.8217281, 'lng': -73.9203167}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8230770802915, 'lng': -73.9189677197085}, 'southwest': {'lat': 40.82037911970851, 'lng': -73.92166568029151}}}, 'place_id': 'ChIJ8YNfQ8z1wokRrR9P-rTNtAQ', 'plus_code': {'compound_code': 'R3CH+MV New York, United States', 'global_code': '87G8R3CH+MV'}, 'types': ['street_address']}
# {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1257', 'short_name': '1257', 'types': ['street_number']}, {'long_name': 'Ogden Avenue', 'short_name': 'Ogden Ave', 'types': ['route']}, {'long_name': 'Highbridge', 'short_name': 'Highbridge', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '2905', 'short_name': '2905', 'types': ['postal_code_suffix']}], 'formatted_address': '1257 Ogden Ave, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8400858, 'lng': -73.9254871}, 'southwest': {'lat': 40.8393746, 'lng': -73.92633839999999}}, 'location': {'lat': 40.8397377, 'lng': -73.9257866}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8410791802915, 'lng': -73.92456376970848}, 'southwest': {'lat': 40.8383812197085, 'lng': -73.9272617302915}}}, 'place_id': 'ChIJq3ejvST0wokRXaiGZX5LxC8', 'types': ['premise']}
# {'long_name': '2905', 'short_name': '2905', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '234', 'short_name': '234', 'types': ['street_number']}, {'long_name': 'East 149th Street', 'short_name': 'E 149th St', 'types': ['route']}, {'long_name': 'Mott Haven', 'short_name': 'Mott Haven', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}, {'long_name': '5504', 'short_name': '5504', 'types': ['postal_code_suffix']}], 'formatted_address': '234 E 149th St, Bronx, NY 10451, USA', 'geometry': {'location': {'lat': 40.817374, 'lng': -73.9240962}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8187229802915, 'lng': -73.92274721970848}, 'southwest': {'lat': 40.8160250197085, 'lng': -73.92544518029149}}}, 'place_id': 'ChIJN_F618_1wokRQPepDvne-ME', 'plus_code': {'compound_code': 'R38G+W9 New York, United States', 'global_code': '87G8R38G+W9'}, 'types': ['street_address']}
# {'long_name': '5504', 'short_name': '5504', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '450', 'short_name': '450', 'types': ['street_number']}, {'long_name': "Saint Ann's Avenue", 'short_name': "St Ann's Ave", 'types': ['route']}, {'long_name': 'Mott Haven', 'short_name': 'Mott Haven', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10455', 'short_name': '10455', 'types': ['postal_code']}, {'long_name': '4263', 'short_name': '4263', 'types': ['postal_code_suffix']}], 'formatted_address': "450 St Ann's Ave, Bronx, NY 10455, USA", 'geometry': {'bounds': {'northeast': {'lat': 40.8117711, 'lng': -73.9136922}, 'southwest': {'lat': 40.8111651, 'lng': -73.9144403}}, 'location': {'lat': 40.8113602, 'lng': -73.914075}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8128170802915, 'lng': -73.9127172697085}, 'southwest': {'lat': 40.8101191197085, 'lng': -73.9154152302915}}}, 'place_id': 'ChIJkanjDMf1wokRHvI-fKU70GU', 'types': ['premise']}
# {'long_name': '4263', 'short_name': '4263', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '595', 'short_name': '595', 'types': ['street_number']}, {'long_name': 'Trinity Avenue', 'short_name': 'Trinity Ave', 'types': ['route']}, {'long_name': 'Woodstock', 'short_name': 'Woodstock', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10455', 'short_name': '10455', 'types': ['postal_code']}], 'formatted_address': '595 Trinity Ave, Bronx, NY 10455, USA', 'geometry': {'location': {'lat': 40.8151267, 'lng': -73.9097285}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8164756802915, 'lng': -73.9083795197085}, 'southwest': {'lat': 40.8137777197085, 'lng': -73.91107748029151}}}, 'place_id': 'ChIJOUiyobf1wokRf5uMrZq-7Rk', 'plus_code': {'compound_code': 'R38R+34 New York, United States', 'global_code': '87G8R38R+34'}, 'types': ['street_address']}
# {'long_name': '10455', 'short_name': '10455', 'types': ['postal_code']}
# {'address_components': [{'long_name': '85', 'short_name': '85', 'types': ['street_number']}, {'long_name': 'East 165th Street', 'short_name': 'E 165th St', 'types': ['route']}, {'long_name': 'Concourse', 'short_name': 'Concourse', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '9102', 'short_name': '9102', 'types': ['postal_code_suffix']}], 'formatted_address': '85 E 165th St, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8318835, 'lng': -73.9219057}, 'southwest': {'lat': 40.8315834, 'lng': -73.9222356}}, 'location': {'lat': 40.8317649, 'lng': -73.9220972}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8330824302915, 'lng': -73.92072166970848}, 'southwest': {'lat': 40.83038446970851, 'lng': -73.92341963029149}}}, 'place_id': 'ChIJt9snvTH0wokRrVsM90tGfSA', 'types': ['premise']}
# {'long_name': '9102', 'short_name': '9102', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '85', 'short_name': '85', 'types': ['street_number']}, {'long_name': 'East 165th Street', 'short_name': 'E 165th St', 'types': ['route']}, {'long_name': 'Concourse', 'short_name': 'Concourse', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '9102', 'short_name': '9102', 'types': ['postal_code_suffix']}], 'formatted_address': '85 E 165th St, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8318835, 'lng': -73.9219057}, 'southwest': {'lat': 40.8315834, 'lng': -73.9222356}}, 'location': {'lat': 40.8317649, 'lng': -73.9220972}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8330824302915, 'lng': -73.92072166970848}, 'southwest': {'lat': 40.83038446970851, 'lng': -73.92341963029149}}}, 'place_id': 'ChIJt9snvTH0wokRrVsM90tGfSA', 'types': ['premise']}
# {'long_name': '9102', 'short_name': '9102', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '1501', 'short_name': '1501', 'types': ['street_number']}, {'long_name': 'Jerome Avenue', 'short_name': 'Jerome Ave', 'types': ['route']}, {'long_name': 'Mount Eden', 'short_name': 'Mount Eden', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '3309', 'short_name': '3309', 'types': ['postal_code_suffix']}], 'formatted_address': '1501 Jerome Ave, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8433553, 'lng': -73.91583179999999}, 'southwest': {'lat': 40.8425823, 'lng': -73.91654}}, 'location': {'lat': 40.8429988, 'lng': -73.9162336}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8443177802915, 'lng': -73.91483691970849}, 'southwest': {'lat': 40.8416198197085, 'lng': -73.9175348802915}}}, 'place_id': 'ChIJE0nbRz70wokRTWnMcdZWq_4', 'types': ['premise']}
# {'long_name': '3309', 'short_name': '3309', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '3225', 'short_name': '3225', 'types': ['street_number']}, {'long_name': 'Reservoir Oval East', 'short_name': 'Reservoir Oval E', 'types': ['route']}, {'long_name': 'Norwood', 'short_name': 'Norwood', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10467', 'short_name': '10467', 'types': ['postal_code']}], 'formatted_address': '3225 Reservoir Oval E, Bronx, NY 10467, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8768713, 'lng': -73.8782727}, 'southwest': {'lat': 40.8764175, 'lng': -73.878896}}, 'location': {'lat': 40.8766392, 'lng': -73.8786141}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.87799338029149, 'lng': -73.8772353697085}, 'southwest': {'lat': 40.87529541970849, 'lng': -73.87993333029151}}}, 'place_id': 'ChIJ13kgk3LzwokRH7K5RheeaEM', 'types': ['premise']}
# {'long_name': '10467', 'short_name': '10467', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1550', 'short_name': '1550', 'types': ['street_number']}, {'long_name': 'Lafayette Avenue', 'short_name': 'Lafayette Ave', 'types': ['route']}, {'long_name': 'Clason Point', 'short_name': 'Clason Point', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10473', 'short_name': '10473', 'types': ['postal_code']}], 'formatted_address': '1550 Lafayette Ave, Bronx, NY 10473, USA', 'geometry': {'location': {'lat': 40.81909479999999, 'lng': -73.87824479999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.82044378029149, 'lng': -73.8768958197085}, 'southwest': {'lat': 40.81774581970849, 'lng': -73.8795937802915}}}, 'place_id': 'ChIJ8xdxgQL1wokRBt5sMSAA40g', 'plus_code': {'compound_code': 'R49C+JP New York, United States', 'global_code': '87G8R49C+JP'}, 'types': ['street_address']}
# {'long_name': '10473', 'short_name': '10473', 'types': ['postal_code']}
# {'address_components': [{'long_name': '340', 'short_name': '340', 'types': ['street_number']}, {'long_name': 'Morris Avenue', 'short_name': 'Morris Ave', 'types': ['route']}, {'long_name': 'Mott Haven', 'short_name': 'Mott Haven', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}], 'formatted_address': '340 Morris Ave, Bronx, NY 10451, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8139669, 'lng': -73.9243973}, 'southwest': {'lat': 40.8134192, 'lng': -73.92507069999999}}, 'location': {'lat': 40.8135891, 'lng': -73.92484739999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8150420302915, 'lng': -73.92338501970849}, 'southwest': {'lat': 40.8123440697085, 'lng': -73.92608298029151}}}, 'place_id': 'ChIJ0yno1tr1wokR6xrq-NFKrDU', 'types': ['premise']}
# {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1527', 'short_name': '1527', 'types': ['street_number']}, {'long_name': 'Jesup Avenue', 'short_name': 'Jesup Ave', 'types': ['route']}, {'long_name': 'Mount Eden', 'short_name': 'Mount Eden', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '1918', 'short_name': '1918', 'types': ['postal_code_suffix']}], 'formatted_address': '1527 Jesup Ave, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8443756, 'lng': -73.9186983}, 'southwest': {'lat': 40.8438385, 'lng': -73.91920259999999}}, 'location': {'lat': 40.8440083, 'lng': -73.9189894}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.84545603029149, 'lng': -73.91760146970849}, 'southwest': {'lat': 40.84275806970849, 'lng': -73.9202994302915}}}, 'place_id': 'ChIJcU3S-j30wokR2CIOR5Sx1wo', 'types': ['premise']}
# {'long_name': '1918', 'short_name': '1918', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '177', 'short_name': '177', 'types': ['street_number']}, {'long_name': 'Dreiser Loop', 'short_name': 'Dreiser Loop', 'types': ['route']}, {'long_name': 'East Bronx', 'short_name': 'East Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10475', 'short_name': '10475', 'types': ['postal_code']}, {'long_name': '2705', 'short_name': '2705', 'types': ['postal_code_suffix']}], 'formatted_address': '177 Dreiser Loop, Bronx, NY 10475, USA', 'geometry': {'location': {'lat': 40.876579, 'lng': -73.8287211}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8779279802915, 'lng': -73.82737211970849}, 'southwest': {'lat': 40.8752300197085, 'lng': -73.83007008029149}}}, 'place_id': 'ChIJj5CTxsWMwokRXsWcmbawarM', 'plus_code': {'compound_code': 'V5GC+JG New York, United States', 'global_code': '87G8V5GC+JG'}, 'types': ['street_address']}
# {'long_name': '2705', 'short_name': '2705', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '286', 'short_name': '286', 'types': ['street_number']}, {'long_name': 'East 156th Street', 'short_name': 'E 156th St', 'types': ['route']}, {'long_name': 'Melrose', 'short_name': 'Melrose', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}], 'formatted_address': '286 E 156th St, Bronx, NY 10451, USA', 'geometry': {'location': {'lat': 40.8217281, 'lng': -73.9203167}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8230770802915, 'lng': -73.9189677197085}, 'southwest': {'lat': 40.82037911970851, 'lng': -73.92166568029151}}}, 'place_id': 'ChIJ8YNfQ8z1wokRrR9P-rTNtAQ', 'plus_code': {'compound_code': 'R3CH+MV New York, United States', 'global_code': '87G8R3CH+MV'}, 'types': ['street_address']}
# {'long_name': '10451', 'short_name': '10451', 'types': ['postal_code']}
# {'address_components': [{'long_name': '2530', 'short_name': '2530', 'types': ['street_number']}, {'long_name': 'Jerome Avenue', 'short_name': 'Jerome Ave', 'types': ['route']}, {'long_name': 'Fordham Manor', 'short_name': 'Fordham Manor', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10468', 'short_name': '10468', 'types': ['postal_code']}, {'long_name': '4300', 'short_name': '4300', 'types': ['postal_code_suffix']}], 'formatted_address': '2530 Jerome Ave, Bronx, NY 10468, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8648501, 'lng': -73.8985624}, 'southwest': {'lat': 40.8642459, 'lng': -73.89937259999999}}, 'location': {'lat': 40.86453729999999, 'lng': -73.89900949999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8658969802915, 'lng': -73.89761851970849}, 'southwest': {'lat': 40.8631990197085, 'lng': -73.90031648029151}}}, 'place_id': 'ChIJWRnpSIbzwokRWGj366J8sNo', 'types': ['premise']}
# {'long_name': '4300', 'short_name': '4300', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '2345', 'short_name': '2345', 'types': ['street_number']}, {'long_name': 'University Avenue', 'short_name': 'University Ave', 'types': ['route']}, {'long_name': 'University Heights', 'short_name': 'University Heights', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10468', 'short_name': '10468', 'types': ['postal_code']}, {'long_name': '6102', 'short_name': '6102', 'types': ['postal_code_suffix']}], 'formatted_address': '2345 University Ave, Bronx, NY 10468, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.86237149999999, 'lng': -73.90557129999999}, 'southwest': {'lat': 40.8621748, 'lng': -73.9058477}}, 'location': {'lat': 40.8622759, 'lng': -73.9056926}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8636221302915, 'lng': -73.90436051970849}, 'southwest': {'lat': 40.8609241697085, 'lng': -73.90705848029151}}}, 'place_id': 'ChIJy-u8HHb0wokRK-XiSS1QCLQ', 'types': ['premise']}
# {'long_name': '6102', 'short_name': '6102', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '1000', 'short_name': '1000', 'types': ['street_number']}, {'long_name': 'Rosedale Avenue', 'short_name': 'Rosedale Ave', 'types': ['route']}, {'long_name': 'East Bronx', 'short_name': 'East Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10472', 'short_name': '10472', 'types': ['postal_code']}], 'formatted_address': '1000 Rosedale Ave, Bronx, NY 10472, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8258282, 'lng': -73.8667669}, 'southwest': {'lat': 40.8253942, 'lng': -73.8675389}}, 'location': {'lat': 40.825536, 'lng': -73.867359}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8269601802915, 'lng': -73.8658039197085}, 'southwest': {'lat': 40.8242622197085, 'lng': -73.8685018802915}}}, 'place_id': 'ChIJIRT9l-f0wokRHByB9RPzz5g', 'types': ['premise']}
# {'long_name': '10472', 'short_name': '10472', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1400', 'short_name': '1400', 'types': ['street_number']}, {'long_name': 'Pelham Parkway South', 'short_name': 'Pelham Pkwy S', 'types': ['route']}, {'long_name': 'Morris Park', 'short_name': 'Morris Park', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10461', 'short_name': '10461', 'types': ['postal_code']}], 'formatted_address': '1400 Pelham Pkwy S, Bronx, NY 10461, USA', 'geometry': {'location': {'lat': 40.8556769, 'lng': -73.8462363}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.85702588029149, 'lng': -73.8448873197085}, 'southwest': {'lat': 40.8543279197085, 'lng': -73.84758528029151}}}, 'place_id': 'ChIJNaMuKVTzwokRfDxfyMl9iw0', 'plus_code': {'compound_code': 'V543+7G New York, United States', 'global_code': '87G8V543+7G'}, 'types': ['street_address']}
# {'long_name': '10461', 'short_name': '10461', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1400', 'short_name': '1400', 'types': ['street_number']}, {'long_name': 'Pelham Parkway South', 'short_name': 'Pelham Pkwy S', 'types': ['route']}, {'long_name': 'Morris Park', 'short_name': 'Morris Park', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10461', 'short_name': '10461', 'types': ['postal_code']}], 'formatted_address': '1400 Pelham Pkwy S, Bronx, NY 10461, USA', 'geometry': {'location': {'lat': 40.8556769, 'lng': -73.8462363}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.85702588029149, 'lng': -73.8448873197085}, 'southwest': {'lat': 40.8543279197085, 'lng': -73.84758528029151}}}, 'place_id': 'ChIJNaMuKVTzwokRfDxfyMl9iw0', 'plus_code': {'compound_code': 'V543+7G New York, United States', 'global_code': '87G8V543+7G'}, 'types': ['street_address']}
# {'long_name': '10461', 'short_name': '10461', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1501', 'short_name': '1501', 'types': ['street_number']}, {'long_name': 'Jerome Avenue', 'short_name': 'Jerome Ave', 'types': ['route']}, {'long_name': 'Mount Eden', 'short_name': 'Mount Eden', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '3309', 'short_name': '3309', 'types': ['postal_code_suffix']}], 'formatted_address': '1501 Jerome Ave, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8433553, 'lng': -73.91583179999999}, 'southwest': {'lat': 40.8425823, 'lng': -73.91654}}, 'location': {'lat': 40.8429988, 'lng': -73.9162336}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8443177802915, 'lng': -73.91483691970849}, 'southwest': {'lat': 40.8416198197085, 'lng': -73.9175348802915}}}, 'place_id': 'ChIJE0nbRz70wokRTWnMcdZWq_4', 'types': ['premise']}
# {'long_name': '3309', 'short_name': '3309', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '2640', 'short_name': '2640', 'types': ['street_number']}, {'long_name': 'Grand Concourse', 'short_name': 'Grand Concourse', 'types': ['route']}, {'long_name': 'Fordham Manor', 'short_name': 'Fordham Manor', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10458', 'short_name': '10458', 'types': ['postal_code']}, {'long_name': '4968', 'short_name': '4968', 'types': ['postal_code_suffix']}], 'formatted_address': '2640 Grand Concourse, Bronx, NY 10458, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8652247, 'lng': -73.8945126}, 'southwest': {'lat': 40.8649401, 'lng': -73.8947993}}, 'location': {'lat': 40.86509179999999, 'lng': -73.89466879999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8664313802915, 'lng': -73.89330696970849}, 'southwest': {'lat': 40.8637334197085, 'lng': -73.89600493029151}}}, 'place_id': 'ChIJm_z4TIHzwokRBEk9OdZULCo', 'types': ['premise']}
# {'long_name': '4968', 'short_name': '4968', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '1400', 'short_name': '1400', 'types': ['street_number']}, {'long_name': 'Pelham Parkway South', 'short_name': 'Pelham Pkwy S', 'types': ['route']}, {'long_name': 'Morris Park', 'short_name': 'Morris Park', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10461', 'short_name': '10461', 'types': ['postal_code']}], 'formatted_address': '1400 Pelham Pkwy S, Bronx, NY 10461, USA', 'geometry': {'location': {'lat': 40.8556769, 'lng': -73.8462363}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.85702588029149, 'lng': -73.8448873197085}, 'southwest': {'lat': 40.8543279197085, 'lng': -73.84758528029151}}}, 'place_id': 'ChIJNaMuKVTzwokRfDxfyMl9iw0', 'plus_code': {'compound_code': 'V543+7G New York, United States', 'global_code': '87G8V543+7G'}, 'types': ['street_address']}
# {'long_name': '10461', 'short_name': '10461', 'types': ['postal_code']}
# {'address_components': [{'long_name': '3350', 'short_name': '3350', 'types': ['street_number']}, {'long_name': 'Bailey Avenue', 'short_name': 'Bailey Ave', 'types': ['route']}, {'long_name': 'West Bronx', 'short_name': 'West Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10463', 'short_name': '10463', 'types': ['postal_code']}], 'formatted_address': '3350 Bailey Ave, Bronx, NY 10463, USA', 'geometry': {'location': {'lat': 40.8798897, 'lng': -73.90045769999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8812386802915, 'lng': -73.8991087197085}, 'southwest': {'lat': 40.8785407197085, 'lng': -73.9018066802915}}}, 'place_id': 'ChIJIyeRJpjzwokRFCO3qc3ds8k', 'plus_code': {'compound_code': 'V3HX+XR New York, United States', 'global_code': '87G8V3HX+XR'}, 'types': ['street_address']}
# {'long_name': '10463', 'short_name': '10463', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1826', 'short_name': '1826', 'types': ['street_number']}, {'long_name': 'Arthur Avenue', 'short_name': 'Arthur Ave', 'types': ['route']}, {'long_name': 'West Bronx', 'short_name': 'West Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10457', 'short_name': '10457', 'types': ['postal_code']}], 'formatted_address': '1826 Arthur Ave, Bronx, NY 10457, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8442896, 'lng': -73.8938679}, 'southwest': {'lat': 40.8438985, 'lng': -73.894361}}, 'location': {'lat': 40.8441212, 'lng': -73.89414049999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.84544303029149, 'lng': -73.89276546970851}, 'southwest': {'lat': 40.8427450697085, 'lng': -73.89546343029151}}}, 'place_id': 'ChIJRbx_L2H0wokRAx2R_HsQg94', 'types': ['premise']}
# {'long_name': '10457', 'short_name': '10457', 'types': ['postal_code']}
# {'address_components': [{'long_name': '190', 'short_name': '190', 'types': ['subpremise']}, {'long_name': '188', 'short_name': '188', 'types': ['street_number']}, {'long_name': 'Lincoln Avenue', 'short_name': 'Lincoln Ave', 'types': ['route']}, {'long_name': 'Mott Haven', 'short_name': 'Mott Haven', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10454', 'short_name': '10454', 'types': ['postal_code']}, {'long_name': '3736', 'short_name': '3736', 'types': ['postal_code_suffix']}], 'formatted_address': '188 Lincoln Ave #190, Bronx, NY 10454, USA', 'geometry': {'location': {'lat': 40.809537, 'lng': -73.9268572}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8108859802915, 'lng': -73.9255082197085}, 'southwest': {'lat': 40.8081880197085, 'lng': -73.92820618029151}}}, 'place_id': 'ChIJJXA599z1wokRx-Yndn_ItQo', 'types': ['subpremise']}
# {'long_name': '3736', 'short_name': '3736', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '3016', 'short_name': '3016', 'types': ['street_number']}, {'long_name': 'Yates Avenue', 'short_name': 'Yates Ave', 'types': ['route']}, {'long_name': 'Laconia', 'short_name': 'Laconia', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10469', 'short_name': '10469', 'types': ['postal_code']}], 'formatted_address': '3016 Yates Ave, Bronx, NY 10469, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8703224, 'lng': -73.8536129}, 'southwest': {'lat': 40.8697414, 'lng': -73.85435500000001}}, 'location': {'lat': 40.8699312, 'lng': -73.8538061}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8713808802915, 'lng': -73.8526349697085}, 'southwest': {'lat': 40.8686829197085, 'lng': -73.85533293029152}}}, 'place_id': 'ChIJqa7fAEbzwokRVoipn5zQo38', 'types': ['premise']}
# {'long_name': '10469', 'short_name': '10469', 'types': ['postal_code']}
# {'address_components': [{'long_name': '650', 'short_name': '650', 'types': ['street_number']}, {'long_name': 'Hollywood Avenue', 'short_name': 'Hollywood Ave', 'types': ['route']}, {'long_name': 'East Bronx', 'short_name': 'East Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10465', 'short_name': '10465', 'types': ['postal_code']}, {'long_name': '2352', 'short_name': '2352', 'types': ['postal_code_suffix']}], 'formatted_address': '650 Hollywood Ave, Bronx, NY 10465, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.827589, 'lng': -73.81762599999999}, 'southwest': {'lat': 40.8264047, 'lng': -73.81891700000001}}, 'location': {'lat': 40.8269794, 'lng': -73.8182885}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8283458302915, 'lng': -73.81692251970851}, 'southwest': {'lat': 40.8256478697085, 'lng': -73.81962048029152}}}, 'place_id': 'ChIJOYrdixWLwokRwuxW2hL7zQQ', 'types': ['premise']}
# {'long_name': '2352', 'short_name': '2352', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '1501', 'short_name': '1501', 'types': ['street_number']}, {'long_name': 'Jerome Avenue', 'short_name': 'Jerome Ave', 'types': ['route']}, {'long_name': 'Mount Eden', 'short_name': 'Mount Eden', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10452', 'short_name': '10452', 'types': ['postal_code']}, {'long_name': '3309', 'short_name': '3309', 'types': ['postal_code_suffix']}], 'formatted_address': '1501 Jerome Ave, Bronx, NY 10452, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8433553, 'lng': -73.91583179999999}, 'southwest': {'lat': 40.8425823, 'lng': -73.91654}}, 'location': {'lat': 40.8429988, 'lng': -73.9162336}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8443177802915, 'lng': -73.91483691970849}, 'southwest': {'lat': 40.8416198197085, 'lng': -73.9175348802915}}}, 'place_id': 'ChIJE0nbRz70wokRTWnMcdZWq_4', 'types': ['premise']}
# {'long_name': '3309', 'short_name': '3309', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '660', 'short_name': '660', 'types': ['street_number']}, {'long_name': 'Fox Street', 'short_name': 'Fox St', 'types': ['route']}, {'long_name': 'Woodstock', 'short_name': 'Woodstock', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10455', 'short_name': '10455', 'types': ['postal_code']}], 'formatted_address': '660 Fox St, Bronx, NY 10455, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.81409379999999, 'lng': -73.89980369999999}, 'southwest': {'lat': 40.8136564, 'lng': -73.9005767}}, 'location': {'lat': 40.8138781, 'lng': -73.9003875}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.81522408029149, 'lng': -73.89884121970849}, 'southwest': {'lat': 40.81252611970849, 'lng': -73.9015391802915}}}, 'place_id': 'ChIJee9G3K_1wokREE-_uUNn8gE', 'types': ['premise']}
# {'long_name': '10455', 'short_name': '10455', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1680', 'short_name': '1680', 'types': ['street_number']}, {'long_name': 'Seward Avenue', 'short_name': 'Seward Ave', 'types': ['route']}, {'long_name': 'Clason Point', 'short_name': 'Clason Point', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10473', 'short_name': '10473', 'types': ['postal_code']}], 'formatted_address': '1680 Seward Ave, Bronx, NY 10473, USA', 'geometry': {'location': {'lat': 40.8180551, 'lng': -73.8688605}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8194040802915, 'lng': -73.86751151970849}, 'southwest': {'lat': 40.8167061197085, 'lng': -73.8702094802915}}}, 'place_id': 'ChIJxbHD1uH0wokRZYW2KJifm8w', 'plus_code': {'compound_code': 'R49J+6F New York, United States', 'global_code': '87G8R49J+6F'}, 'types': ['street_address']}
# {'long_name': '10473', 'short_name': '10473', 'types': ['postal_code']}
# {'address_components': [{'long_name': '1619', 'short_name': '1619', 'types': ['street_number']}, {'long_name': 'East 174th Street', 'short_name': 'E 174th St', 'types': ['route']}, {'long_name': 'East Bronx', 'short_name': 'East Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10472', 'short_name': '10472', 'types': ['postal_code']}, {'long_name': '1363', 'short_name': '1363', 'types': ['postal_code_suffix']}], 'formatted_address': '1619 E 174th St, Bronx, NY 10472, USA', 'geometry': {'location': {'lat': 40.8349573, 'lng': -73.87634369999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8363062802915, 'lng': -73.87499471970848}, 'southwest': {'lat': 40.8336083197085, 'lng': -73.87769268029149}}}, 'place_id': 'ChIJEUJ1je30wokRvocsaCL8GB8', 'plus_code': {'compound_code': 'R4MF+XF New York, United States', 'global_code': '87G8R4MF+XF'}, 'types': ['street_address']}
# {'long_name': '1363', 'short_name': '1363', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '1619', 'short_name': '1619', 'types': ['street_number']}, {'long_name': 'East 174th Street', 'short_name': 'E 174th St', 'types': ['route']}, {'long_name': 'East Bronx', 'short_name': 'East Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10472', 'short_name': '10472', 'types': ['postal_code']}, {'long_name': '1363', 'short_name': '1363', 'types': ['postal_code_suffix']}], 'formatted_address': '1619 E 174th St, Bronx, NY 10472, USA', 'geometry': {'location': {'lat': 40.8349573, 'lng': -73.87634369999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8363062802915, 'lng': -73.87499471970848}, 'southwest': {'lat': 40.8336083197085, 'lng': -73.87769268029149}}}, 'place_id': 'ChIJEUJ1je30wokRvocsaCL8GB8', 'plus_code': {'compound_code': 'R4MF+XF New York, United States', 'global_code': '87G8R4MF+XF'}, 'types': ['street_address']}
# {'long_name': '1363', 'short_name': '1363', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '2049', 'short_name': '2049', 'types': ['street_number']}, {'long_name': 'Bartow Avenue', 'short_name': 'Bartow Ave', 'types': ['route']}, {'long_name': 'East Bronx', 'short_name': 'East Bronx', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10475', 'short_name': '10475', 'types': ['postal_code']}, {'long_name': '4613', 'short_name': '4613', 'types': ['postal_code_suffix']}], 'formatted_address': '2049 Bartow Ave, Bronx, NY 10475, USA', 'geometry': {'location': {'lat': 40.8704537, 'lng': -73.82911109999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.87180268029149, 'lng': -73.8277621197085}, 'southwest': {'lat': 40.8691047197085, 'lng': -73.8304600802915}}}, 'place_id': 'ChIJdxHfTsaMwokRx1wnGDtLrbs', 'plus_code': {'compound_code': 'V5CC+59 New York, United States', 'global_code': '87G8V5CC+59'}, 'types': ['street_address']}
# {'long_name': '4613', 'short_name': '4613', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '2640', 'short_name': '2640', 'types': ['street_number']}, {'long_name': 'Grand Concourse', 'short_name': 'Grand Concourse', 'types': ['route']}, {'long_name': 'Fordham Manor', 'short_name': 'Fordham Manor', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10458', 'short_name': '10458', 'types': ['postal_code']}, {'long_name': '4968', 'short_name': '4968', 'types': ['postal_code_suffix']}], 'formatted_address': '2640 Grand Concourse, Bronx, NY 10458, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8652247, 'lng': -73.8945126}, 'southwest': {'lat': 40.8649401, 'lng': -73.8947993}}, 'location': {'lat': 40.86509179999999, 'lng': -73.89466879999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8664313802915, 'lng': -73.89330696970849}, 'southwest': {'lat': 40.8637334197085, 'lng': -73.89600493029151}}}, 'place_id': 'ChIJm_z4TIHzwokRBEk9OdZULCo', 'types': ['premise']}
# {'long_name': '4968', 'short_name': '4968', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '2530', 'short_name': '2530', 'types': ['street_number']}, {'long_name': 'Jerome Avenue', 'short_name': 'Jerome Ave', 'types': ['route']}, {'long_name': 'Fordham Manor', 'short_name': 'Fordham Manor', 'types': ['neighborhood', 'political']}, {'long_name': 'Bronx', 'short_name': 'Bronx', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Bronx County', 'short_name': 'Bronx County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10468', 'short_name': '10468', 'types': ['postal_code']}, {'long_name': '4300', 'short_name': '4300', 'types': ['postal_code_suffix']}], 'formatted_address': '2530 Jerome Ave, Bronx, NY 10468, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.8648501, 'lng': -73.8985624}, 'southwest': {'lat': 40.8642459, 'lng': -73.89937259999999}}, 'location': {'lat': 40.86453729999999, 'lng': -73.89900949999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.8658969802915, 'lng': -73.89761851970849}, 'southwest': {'lat': 40.8631990197085, 'lng': -73.90031648029151}}}, 'place_id': 'ChIJWRnpSIbzwokRWGj366J8sNo', 'types': ['premise']}
# ...
# {'long_name': '5073', 'short_name': '5073', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '71', 'short_name': '71', 'types': ['street_number']}, {'long_name': 'Jersey Street', 'short_name': 'Jersey St', 'types': ['route']}, {'long_name': 'St. George', 'short_name': 'St. George', 'types': ['neighborhood', 'political']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10301', 'short_name': '10301', 'types': ['postal_code']}], 'formatted_address': '71 Jersey St, Staten Island, NY 10301, USA', 'geometry': {'location': {'lat': 40.64587059999999, 'lng': -74.0878857}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6472195802915, 'lng': -74.08653671970849}, 'southwest': {'lat': 40.6445216197085, 'lng': -74.08923468029151}}}, 'place_id': 'ChIJafaTTS9OwokRMl2t3hZGTIw', 'plus_code': {'compound_code': 'JWW6+8R New York, United States', 'global_code': '87G7JWW6+8R'}, 'types': ['street_address']}
# {'long_name': '10301', 'short_name': '10301', 'types': ['postal_code']}
# {'address_components': [{'long_name': '6', 'short_name': '6', 'types': ['street_number']}, {'long_name': 'Victory Boulevard', 'short_name': 'Victory Blvd', 'types': ['route']}, {'long_name': 'Tompkinsville', 'short_name': 'Tompkinsville', 'types': ['neighborhood', 'political']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10301', 'short_name': '10301', 'types': ['postal_code']}], 'formatted_address': '6 Victory Blvd, Staten Island, NY 10301, USA', 'geometry': {'location': {'lat': 40.6376092, 'lng': -74.0743925}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6389581802915, 'lng': -74.07304351970849}, 'southwest': {'lat': 40.6362602197085, 'lng': -74.07574148029151}}}, 'place_id': 'ChIJWfGlCM1PwokRJKA6yeXfNtY', 'plus_code': {'compound_code': 'JWQG+26 New York, United States', 'global_code': '87G7JWQG+26'}, 'types': ['street_address']}
# {'long_name': '10301', 'short_name': '10301', 'types': ['postal_code']}
# {'address_components': [{'long_name': '6', 'short_name': '6', 'types': ['street_number']}, {'long_name': 'Victory Boulevard', 'short_name': 'Victory Blvd', 'types': ['route']}, {'long_name': 'Tompkinsville', 'short_name': 'Tompkinsville', 'types': ['neighborhood', 'political']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10301', 'short_name': '10301', 'types': ['postal_code']}], 'formatted_address': '6 Victory Blvd, Staten Island, NY 10301, USA', 'geometry': {'location': {'lat': 40.6376092, 'lng': -74.0743925}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6389581802915, 'lng': -74.07304351970849}, 'southwest': {'lat': 40.6362602197085, 'lng': -74.07574148029151}}}, 'place_id': 'ChIJWfGlCM1PwokRJKA6yeXfNtY', 'plus_code': {'compound_code': 'JWQG+26 New York, United States', 'global_code': '87G7JWQG+26'}, 'types': ['street_address']}
# {'long_name': '10301', 'short_name': '10301', 'types': ['postal_code']}
# {'address_components': [{'long_name': '501', 'short_name': '501', 'types': ['street_number']}, {'long_name': 'Brielle Avenue', 'short_name': 'Brielle Ave', 'types': ['route']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10314', 'short_name': '10314', 'types': ['postal_code']}], 'formatted_address': '501 Brielle Ave, Staten Island, NY 10314, USA', 'geometry': {'location': {'lat': 40.5918312, 'lng': -74.13919899999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.5931801802915, 'lng': -74.1378500197085}, 'southwest': {'lat': 40.59048221970851, 'lng': -74.1405479802915}}}, 'place_id': 'ChIJk4yuBxFMwokRQ7fotgXjEg8', 'plus_code': {'compound_code': 'HVR6+P8 New York, United States', 'global_code': '87G7HVR6+P8'}, 'types': ['establishment', 'gym', 'health', 'point_of_interest']}
# {'long_name': '10314', 'short_name': '10314', 'types': ['postal_code']}
# {'address_components': [{'long_name': '80', 'short_name': '80', 'types': ['street_number']}, {'long_name': 'Union Avenue', 'short_name': 'Union Ave', 'types': ['route']}, {'long_name': 'Broadway Triangle', 'short_name': 'Broadway Triangle', 'types': ['neighborhood', 'political']}, {'long_name': 'Brooklyn', 'short_name': 'Brooklyn', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Kings County', 'short_name': 'Kings County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '11206', 'short_name': '11206', 'types': ['postal_code']}, {'long_name': '5073', 'short_name': '5073', 'types': ['postal_code_suffix']}], 'formatted_address': '80 Union Ave, Brooklyn, NY 11206, USA', 'geometry': {'location': {'lat': 40.7023148, 'lng': -73.9499096}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.7036637802915, 'lng': -73.9485606197085}, 'southwest': {'lat': 40.7009658197085, 'lng': -73.95125858029151}}}, 'place_id': 'ChIJA7KbEuVbwokRMVTr-1-1qJ4', 'plus_code': {'compound_code': 'P322+W2 New York, United States', 'global_code': '87G8P322+W2'}, 'types': ['street_address']}
# {'long_name': '5073', 'short_name': '5073', 'types': ['postal_code_suffix']}
# {'address_components': [{'long_name': '1331', 'short_name': '1331', 'types': ['street_number']}, {'long_name': 'Bay Street', 'short_name': 'Bay St', 'types': ['route']}, {'long_name': 'Shore Acres', 'short_name': 'Shore Acres', 'types': ['neighborhood', 'political']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10305', 'short_name': '10305', 'types': ['postal_code']}], 'formatted_address': '1331 Bay St, Staten Island, NY 10305, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.6118575, 'lng': -74.06274239999999}, 'southwest': {'lat': 40.6113626, 'lng': -74.06327449999999}}, 'location': {'lat': 40.6116447, 'lng': -74.0630128}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6129590302915, 'lng': -74.06165946970849}, 'southwest': {'lat': 40.6102610697085, 'lng': -74.06435743029151}}}, 'place_id': 'ChIJiaSZXKZPwokRQJzd29_SlFM', 'types': ['premise']}
# {'long_name': '10305', 'short_name': '10305', 'types': ['postal_code']}
# {'address_components': [{'long_name': '501', 'short_name': '501', 'types': ['street_number']}, {'long_name': 'Brielle Avenue', 'short_name': 'Brielle Ave', 'types': ['route']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10314', 'short_name': '10314', 'types': ['postal_code']}], 'formatted_address': '501 Brielle Ave, Staten Island, NY 10314, USA', 'geometry': {'location': {'lat': 40.5918312, 'lng': -74.13919899999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.5931801802915, 'lng': -74.1378500197085}, 'southwest': {'lat': 40.59048221970851, 'lng': -74.1405479802915}}}, 'place_id': 'ChIJk4yuBxFMwokRQ7fotgXjEg8', 'plus_code': {'compound_code': 'HVR6+P8 New York, United States', 'global_code': '87G7HVR6+P8'}, 'types': ['establishment', 'gym', 'health', 'point_of_interest']}
# {'long_name': '10314', 'short_name': '10314', 'types': ['postal_code']}
# {'address_components': [{'long_name': '2175', 'short_name': '2175', 'types': ['street_number']}, {'long_name': 'Richmond Terrace', 'short_name': 'Richmond Terrace', 'types': ['route']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10302', 'short_name': '10302', 'types': ['postal_code']}], 'formatted_address': '2175 Richmond Terrace, Staten Island, NY 10302, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.641079, 'lng': -74.1351589}, 'southwest': {'lat': 40.6409619, 'lng': -74.13566569999999}}, 'location': {'lat': 40.6410298, 'lng': -74.1354195}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6423694302915, 'lng': -74.13406331970849}, 'southwest': {'lat': 40.6396714697085, 'lng': -74.1367612802915}}}, 'place_id': 'ChIJU1wwKeZNwokRMtBNITOk10I', 'types': ['premise']}
# {'long_name': '10302', 'short_name': '10302', 'types': ['postal_code']}
# {'address_components': [{'long_name': '2175', 'short_name': '2175', 'types': ['street_number']}, {'long_name': 'Richmond Terrace', 'short_name': 'Richmond Terrace', 'types': ['route']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10302', 'short_name': '10302', 'types': ['postal_code']}], 'formatted_address': '2175 Richmond Terrace, Staten Island, NY 10302, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.641079, 'lng': -74.1351589}, 'southwest': {'lat': 40.6409619, 'lng': -74.13566569999999}}, 'location': {'lat': 40.6410298, 'lng': -74.1354195}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6423694302915, 'lng': -74.13406331970849}, 'southwest': {'lat': 40.6396714697085, 'lng': -74.1367612802915}}}, 'place_id': 'ChIJU1wwKeZNwokRMtBNITOk10I', 'types': ['premise']}
# {'long_name': '10302', 'short_name': '10302', 'types': ['postal_code']}
# {'address_components': [{'long_name': '501', 'short_name': '501', 'types': ['street_number']}, {'long_name': 'Brielle Avenue', 'short_name': 'Brielle Ave', 'types': ['route']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10314', 'short_name': '10314', 'types': ['postal_code']}], 'formatted_address': '501 Brielle Ave, Staten Island, NY 10314, USA', 'geometry': {'location': {'lat': 40.5918312, 'lng': -74.13919899999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.5931801802915, 'lng': -74.1378500197085}, 'southwest': {'lat': 40.59048221970851, 'lng': -74.1405479802915}}}, 'place_id': 'ChIJk4yuBxFMwokRQ7fotgXjEg8', 'plus_code': {'compound_code': 'HVR6+P8 New York, United States', 'global_code': '87G7HVR6+P8'}, 'types': ['establishment', 'gym', 'health', 'point_of_interest']}
# {'long_name': '10314', 'short_name': '10314', 'types': ['postal_code']}
# {'address_components': [{'long_name': '150', 'short_name': '150', 'types': ['street_number']}, {'long_name': 'Granite Avenue', 'short_name': 'Granite Ave', 'types': ['route']}, {'long_name': 'Mariners Harbor', 'short_name': 'Mariners Harbor', 'types': ['neighborhood', 'political']}, {'long_name': 'Staten Island', 'short_name': 'Staten Island', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Richmond County', 'short_name': 'Richmond County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10303', 'short_name': '10303', 'types': ['postal_code']}, {'long_name': '2718', 'short_name': '2718', 'types': ['postal_code_suffix']}], 'formatted_address': '150 Granite Ave, Staten Island, NY 10303, USA', 'geometry': {'bounds': {'northeast': {'lat': 40.6339036, 'lng': -74.1484629}, 'southwest': {'lat': 40.6333925, 'lng': -74.1489397}}, 'location': {'lat': 40.6335665, 'lng': -74.1486773}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.6349970302915, 'lng': -74.1473523197085}, 'southwest': {'lat': 40.6322990697085, 'lng': -74.15005028029151}}}, 'place_id': 'ChIJo9ZLlLhNwokRrPDRCNPD3TA', 'types': ['premise']}
# {'long_name': '2718', 'short_name': '2718', 'types': ['postal_code_suffix']}
#                   address                        category  \
# 0   286 East 156th Street                  Aerobic Dance
# 1          1257 Ogden Ave  Bilingual Belly Dance Fitness
# 2   234 East 149th Street        Bilingual Dance Fitness
# 3  450 Saint Ann's Avenue                Bilingual Zumba
# 4         595 Trinity Ave                Bilingual Zumba
#
#                     center_name        day    end_time start_time length  \
# 0     Bronxworks Classic Center   Thursday   8:00 p.m.  7:00 p.m.  60min
# 1                       P.S. 11  Wednesday  10:30 a.m.  9:00 a.m.  90min
# 2              Lincoln Hospital   Thursday   7:00 p.m.  6:00 p.m.  60min
# 3  St. Mary’s Recreation Center   Thursday   8:00 p.m.  7:00 p.m.  60min
# 4   St. Mary's Community Center  Wednesday   8:00 p.m.  7:00 p.m.  60min
#
#   zip_code
# 0    10451
# 1    10452
# 2    10451
# 3    10455
# 4    10455

# %%
park["price"] = "Free"
# Out:
#                   address                        category  \
# 0   286 East 156th Street                  Aerobic Dance
# 1          1257 Ogden Ave  Bilingual Belly Dance Fitness
# 2   234 East 149th Street        Bilingual Dance Fitness
# 3  450 Saint Ann's Avenue                Bilingual Zumba
# 4         595 Trinity Ave                Bilingual Zumba
#
#                     center_name        day    end_time start_time length  \
# 0     Bronxworks Classic Center   Thursday   8:00 p.m.  7:00 p.m.  60min
# 1                       P.S. 11  Wednesday  10:30 a.m.  9:00 a.m.  90min
# 2              Lincoln Hospital   Thursday   7:00 p.m.  6:00 p.m.  60min
# 3  St. Mary’s Recreation Center   Thursday   8:00 p.m.  7:00 p.m.  60min
# 4   St. Mary's Community Center  Wednesday   8:00 p.m.  7:00 p.m.  60min
#
#   zip_code price
# 0    10451  Free
# 1    10452  Free
# 2    10451  Free
# 3    10455  Free
# 4    10455  Free

# %%
park['url'] = "https://www.nycgovparks.org/programs/recreation/shape-up-nyc?fbclid=IwAR2fu7flf3TdXJicDvHYsTDBBlI054ECUvKGhAjR6nqKj4CQbiDvURdegLk"
park.head()
# Out:
#                   address                        category  \
# 0   286 East 156th Street                  Aerobic Dance
# 1          1257 Ogden Ave  Bilingual Belly Dance Fitness
# 2   234 East 149th Street        Bilingual Dance Fitness
# 3  450 Saint Ann's Avenue                Bilingual Zumba
# 4         595 Trinity Ave                Bilingual Zumba
#
#                     center_name        day    end_time start_time length  \
# 0     Bronxworks Classic Center   Thursday   8:00 p.m.  7:00 p.m.  60min
# 1                       P.S. 11  Wednesday  10:30 a.m.  9:00 a.m.  90min
# 2              Lincoln Hospital   Thursday   7:00 p.m.  6:00 p.m.  60min
# 3  St. Mary’s Recreation Center   Thursday   8:00 p.m.  7:00 p.m.  60min
# 4   St. Mary's Community Center  Wednesday   8:00 p.m.  7:00 p.m.  60min
#
#   zip_code price                                                url
# 0    10451  Free  https://www.nycgovparks.org/programs/recreatio...
# 1    10452  Free  https://www.nycgovparks.org/programs/recreatio...
# 2    10451  Free  https://www.nycgovparks.org/programs/recreatio...
# 3    10455  Free  https://www.nycgovparks.org/programs/recreatio...
# 4    10455  Free  https://www.nycgovparks.org/programs/recreatio...

# %%
park.drop(columns=["end_time"],inplace=True)
park.head()
# Out:
#                   address                        category  \
# 0   286 East 156th Street                  Aerobic Dance
# 1          1257 Ogden Ave  Bilingual Belly Dance Fitness
# 2   234 East 149th Street        Bilingual Dance Fitness
# 3  450 Saint Ann's Avenue                Bilingual Zumba
# 4         595 Trinity Ave                Bilingual Zumba
#
#                     center_name        day start_time length zip_code price  \
# 0     Bronxworks Classic Center   Thursday  7:00 p.m.  60min    10451  Free
# 1                       P.S. 11  Wednesday  9:00 a.m.  90min    10452  Free
# 2              Lincoln Hospital   Thursday  6:00 p.m.  60min    10451  Free
# 3  St. Mary’s Recreation Center   Thursday  7:00 p.m.  60min    10455  Free
# 4   St. Mary's Community Center  Wednesday  7:00 p.m.  60min    10455  Free
#
#                                                  url
# 0  https://www.nycgovparks.org/programs/recreatio...
# 1  https://www.nycgovparks.org/programs/recreatio...
# 2  https://www.nycgovparks.org/programs/recreatio...
# 3  https://www.nycgovparks.org/programs/recreatio...
# 4  https://www.nycgovparks.org/programs/recreatio...

# %%
park = park[["center_name","address","category","day","start_time","length","zip_code","price","url"]]
park.head()
# Out:
#                     center_name                 address  \
# 0     Bronxworks Classic Center   286 East 156th Street
# 1                       P.S. 11          1257 Ogden Ave
# 2              Lincoln Hospital   234 East 149th Street
# 3  St. Mary’s Recreation Center  450 Saint Ann's Avenue
# 4   St. Mary's Community Center         595 Trinity Ave
#
#                          category        day start_time length zip_code price  \
# 0                  Aerobic Dance    Thursday  7:00 p.m.  60min    10451  Free
# 1  Bilingual Belly Dance Fitness   Wednesday  9:00 a.m.  90min    10452  Free
# 2        Bilingual Dance Fitness    Thursday  6:00 p.m.  60min    10451  Free
# 3                Bilingual Zumba    Thursday  7:00 p.m.  60min    10455  Free
# 4                Bilingual Zumba   Wednesday  7:00 p.m.  60min    10455  Free
#
#                                                  url
# 0  https://www.nycgovparks.org/programs/recreatio...
# 1  https://www.nycgovparks.org/programs/recreatio...
# 2  https://www.nycgovparks.org/programs/recreatio...
# 3  https://www.nycgovparks.org/programs/recreatio...
# 4  https://www.nycgovparks.org/programs/recreatio...

# %%
park = park.rename(index=str,columns={"center_name":"center"})
park.head()
# Out:
#                          center                 address  \
# 0     Bronxworks Classic Center   286 East 156th Street
# 1                       P.S. 11          1257 Ogden Ave
# 2              Lincoln Hospital   234 East 149th Street
# 3  St. Mary’s Recreation Center  450 Saint Ann's Avenue
# 4   St. Mary's Community Center         595 Trinity Ave
#
#                             class        day start_time length zip_code price  \
# 0                  Aerobic Dance    Thursday  7:00 p.m.  60min    10451  Free
# 1  Bilingual Belly Dance Fitness   Wednesday  9:00 a.m.  90min    10452  Free
# 2        Bilingual Dance Fitness    Thursday  6:00 p.m.  60min    10451  Free
# 3                Bilingual Zumba    Thursday  7:00 p.m.  60min    10455  Free
# 4                Bilingual Zumba   Wednesday  7:00 p.m.  60min    10455  Free
#
#                                                  url
# 0  https://www.nycgovparks.org/programs/recreatio...
# 1  https://www.nycgovparks.org/programs/recreatio...
# 2  https://www.nycgovparks.org/programs/recreatio...
# 3  https://www.nycgovparks.org/programs/recreatio...
# 4  https://www.nycgovparks.org/programs/recreatio...

# %%
def get_length(df):
    end_time = df["end_time"].split()[0]
    end = datetime.datetime.strptime(end_time, '%H:%M')
    start_time = df["start_time"].split()[0]
    start = datetime.datetime.strptime(start_time, '%H:%M')
    timeDiff = int((end - start).total_seconds() / 60)
    if timeDiff < 0:
        timeDiff = 60
    return str(timeDiff)+"min"

# %%
import datetime
end = datetime.datetime.strptime("13:00", '%H:%M')
start = datetime.datetime.strptime("9:00", '%H:%M')
add = datetime.datetime.strptime("12:00", '%H:%M')
timeDiff = (end - start).total_seconds() / 60
print(timeDiff)
# Out:
# 240

# %%
//park completed

# %%
nysc.head(5)
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#           date length         name                room               time
# 0  Sun, Dec 09  60min  91st & 3rd         [@ Studio 1]  5:30 PM - 6:30 PM
# 1  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  5:30 PM - 6:15 PM
# 2  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  6:30 PM - 7:15 PM
# 3  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  6:30 PM - 7:15 PM
# 4  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  7:15 PM - 8:00 PM

# %%
nysc["zip_code"] = nysc.name.apply(get_postal_code)
nysc["price"] = "Paid"
nysc.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#           date length         name                room               time  \
# 0  Sun, Dec 09  60min  91st & 3rd         [@ Studio 1]  5:30 PM - 6:30 PM
# 1  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  5:30 PM - 6:15 PM
# 2  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  6:30 PM - 7:15 PM
# 3  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  6:30 PM - 7:15 PM
# 4  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  7:15 PM - 8:00 PM
#
#   zip_code price
# 0    10128  Paid
# 1    10128  Paid
# 2    10128  Paid
# 3    10128  Paid
# 4    10128  Paid

# %%
def stripped_time(time):
    start = time.split(" - ")[0]
    if "PM" in start:
        start = start.replace("PM","p.m.")
    elif "AM" in start:
        start = start.replace("AM","a.m.")
    return start

# %%
nysc.time = nysc.time.apply(stripped_time)
nysc.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#           date length         name                room       time zip_code  \
# 0  Sun, Dec 09  60min  91st & 3rd         [@ Studio 1]  5:30 p.m.    10128
# 1  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  5:30 p.m.    10128
# 2  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  6:30 p.m.    10128
# 3  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  6:30 p.m.    10128
# 4  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  7:15 p.m.    10128
#
#   price
# 0  Paid
# 1  Paid
# 2  Paid
# 3  Paid
# 4  Paid

# %%
nysc.date = nysc.date.apply(lambda x: x.split(', ')[0])
nysc.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#   date length         name                room       time zip_code price
# 0  Sun  60min  91st & 3rd         [@ Studio 1]  5:30 p.m.    10128  Paid
# 1  Sun  45min  91st & 3rd   [@ Cycling Studio]  5:30 p.m.    10128  Paid
# 2  Sun  45min  91st & 3rd         [@ Studio 1]  6:30 p.m.    10128  Paid
# 3  Sun  45min  91st & 3rd   [@ Cycling Studio]  6:30 p.m.    10128  Paid
# 4  Sun  45min  91st & 3rd         [@ Studio 1]  7:15 p.m.    10128  Paid

# %%
def fmt_date(date):
    if date == "Sat":
        return "Saturday"
    elif date == "Sun":
        return "Sunday"
    elif date == "Mon":
        return "Monday"
    elif date == "Tue":
        return "Tuesday"
    elif date == "Wed":
        return "Wednesday"
    elif date == "Thu":
        return "Thursday"
    elif date == "Fri":
        return "Friday"

# %%
nysc.date = nysc.date.apply(fmt_date)
nysc.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#      date length         name                room       time zip_code price
# 0  Sunday  60min  91st & 3rd         [@ Studio 1]  5:30 p.m.    10128  Paid
# 1  Sunday  45min  91st & 3rd   [@ Cycling Studio]  5:30 p.m.    10128  Paid
# 2  Sunday  45min  91st & 3rd         [@ Studio 1]  6:30 p.m.    10128  Paid
# 3  Sunday  45min  91st & 3rd   [@ Cycling Studio]  6:30 p.m.    10128  Paid
# 4  Sunday  45min  91st & 3rd         [@ Studio 1]  7:15 p.m.    10128  Paid

# %%
nysc["center"] = "New York Sports Club"
nysc.name = nysc.name.apply(lambda x:"New York Sports Club, "+x+", New York")

# %%
nysc.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#      date length                                         name  \
# 0  Sunday  60min  New York Sports Club, 91st & 3rd , New York
# 1  Sunday  45min  New York Sports Club, 91st & 3rd , New York
# 2  Sunday  45min  New York Sports Club, 91st & 3rd , New York
# 3  Sunday  45min  New York Sports Club, 91st & 3rd , New York
# 4  Sunday  45min  New York Sports Club, 91st & 3rd , New York
#
#                  room       time zip_code price                center
# 0        [@ Studio 1]  5:30 p.m.    10128  Paid  New York Sports Club
# 1  [@ Cycling Studio]  5:30 p.m.    10128  Paid  New York Sports Club
# 2        [@ Studio 1]  6:30 p.m.    10128  Paid  New York Sports Club
# 3  [@ Cycling Studio]  6:30 p.m.    10128  Paid  New York Sports Club
# 4        [@ Studio 1]  7:15 p.m.    10128  Paid  New York Sports Club

# %%
nysc.name = nysc.name.apply(lambda x:x.replace(" ,",","))
nysc.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#      date length                                        name  \
# 0  Sunday  60min  New York Sports Club, 91st & 3rd, New York
# 1  Sunday  45min  New York Sports Club, 91st & 3rd, New York
# 2  Sunday  45min  New York Sports Club, 91st & 3rd, New York
# 3  Sunday  45min  New York Sports Club, 91st & 3rd, New York
# 4  Sunday  45min  New York Sports Club, 91st & 3rd, New York
#
#                  room       time zip_code price                center
# 0        [@ Studio 1]  5:30 p.m.    10128  Paid  New York Sports Club
# 1  [@ Cycling Studio]  5:30 p.m.    10128  Paid  New York Sports Club
# 2        [@ Studio 1]  6:30 p.m.    10128  Paid  New York Sports Club
# 3  [@ Cycling Studio]  6:30 p.m.    10128  Paid  New York Sports Club
# 4        [@ Studio 1]  7:15 p.m.    10128  Paid  New York Sports Club

# %%
nysc.drop(columns = ["Reserve","room"],inplace=True)
nysc.head()
# Out:
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#      date length                                        name       time  \
# 0  Sunday  60min  New York Sports Club, 91st & 3rd, New York  5:30 p.m.
# 1  Sunday  45min  New York Sports Club, 91st & 3rd, New York  5:30 p.m.
# 2  Sunday  45min  New York Sports Club, 91st & 3rd, New York  6:30 p.m.
# 3  Sunday  45min  New York Sports Club, 91st & 3rd, New York  6:30 p.m.
# 4  Sunday  45min  New York Sports Club, 91st & 3rd, New York  7:15 p.m.
#
#   zip_code price                center
# 0    10128  Paid  New York Sports Club
# 1    10128  Paid  New York Sports Club
# 2    10128  Paid  New York Sports Club
# 3    10128  Paid  New York Sports Club
# 4    10128  Paid  New York Sports Club

# %%
nysc = nysc[['center','name','activity','date','time','length','zip_code','price','Try']]
nysc.head()
# Out:
#                  center                                        name  \
# 0  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 1  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 2  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 3  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 4  New York Sports Club  New York Sports Club, 91st & 3rd, New York
#
#                   activity    date       time length zip_code price  \
# 0  Total Body Conditioning  Sunday  5:30 p.m.  60min    10128  Paid
# 1                  Cycling  Sunday  5:30 p.m.  45min    10128  Paid
# 2                     Step  Sunday  6:30 p.m.  45min    10128  Paid
# 3                  Cycling  Sunday  6:30 p.m.  45min    10128  Paid
# 4  Total Body Conditioning  Sunday  7:15 p.m.  45min    10128  Paid
#
#                                                  Try
# 0  https://www.newyorksportsclubs.com/join/try/35...
# 1  https://www.newyorksportsclubs.com/join/try/35...
# 2  https://www.newyorksportsclubs.com/join/try/35...
# 3  https://www.newyorksportsclubs.com/join/try/35...
# 4  https://www.newyorksportsclubs.com/join/try/35...

# %%
nysc = nysc.rename(index=str,columns={"name":"address",'date':"day","Try":"url",'activity':"class"})
nysc.head()
# Out:
#                  center                                     address  \
# 0  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 1  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 2  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 3  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 4  New York Sports Club  New York Sports Club, 91st & 3rd, New York
#
#                      class     day       time length zip_code price  \
# 0  Total Body Conditioning  Sunday  5:30 p.m.  60min    10128  Paid
# 1                  Cycling  Sunday  5:30 p.m.  45min    10128  Paid
# 2                     Step  Sunday  6:30 p.m.  45min    10128  Paid
# 3                  Cycling  Sunday  6:30 p.m.  45min    10128  Paid
# 4  Total Body Conditioning  Sunday  7:15 p.m.  45min    10128  Paid
#
#                                                  url
# 0  https://www.newyorksportsclubs.com/join/try/35...
# 1  https://www.newyorksportsclubs.com/join/try/35...
# 2  https://www.newyorksportsclubs.com/join/try/35...
# 3  https://www.newyorksportsclubs.com/join/try/35...
# 4  https://www.newyorksportsclubs.com/join/try/35...

# %%
nysc = nysc.rename(index=str,columns={"time":"start_time"})
nysc.head()
# Out:
#                  center                                     address  \
# 0  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 1  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 2  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 3  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 4  New York Sports Club  New York Sports Club, 91st & 3rd, New York
#
#                      class     day start_time length zip_code price  \
# 0  Total Body Conditioning  Sunday  5:30 p.m.  60min    10128  Paid
# 1                  Cycling  Sunday  5:30 p.m.  45min    10128  Paid
# 2                     Step  Sunday  6:30 p.m.  45min    10128  Paid
# 3                  Cycling  Sunday  6:30 p.m.  45min    10128  Paid
# 4  Total Body Conditioning  Sunday  7:15 p.m.  45min    10128  Paid
#
#                                                  url
# 0  https://www.newyorksportsclubs.com/join/try/35...
# 1  https://www.newyorksportsclubs.com/join/try/35...
# 2  https://www.newyorksportsclubs.com/join/try/35...
# 3  https://www.newyorksportsclubs.com/join/try/35...
# 4  https://www.newyorksportsclubs.com/join/try/35...

# %%
nysc.shape
# Out:
# (10961, 9)

# %%
nysc = nysc.drop_duplicates()

# %%
nysc.head(50)
# Out:
#                   center                                            address  \
# 0   New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 1   New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 2   New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 3   New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 4   New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 5   New York Sports Club     New York Sports Club, East Brunswick, New York
# 6   New York Sports Club         New York Sports Club, Long Beach, New York
# 7   New York Sports Club          New York Sports Club, Hawthorne, New York
# 8   New York Sports Club           New York Sports Club, Woodmere, New York
# 9   New York Sports Club          New York Sports Club, Smithtown, New York
# 10  New York Sports Club  New York Sports Club, 125th Street  Harlem USA...
# 11  New York Sports Club        New York Sports Club, Garnerville, New York
# 12  New York Sports Club             New York Sports Club, Carmel, New York
# 13  New York Sports Club            New York Sports Club, Clifton, New York
# 14  New York Sports Club          New York Sports Club, Montclair, New York
# 15  New York Sports Club      New York Sports Club, West Hartford, New York
# 16  New York Sports Club          New York Sports Club, Scarsdale, New York
# 17  New York Sports Club         New York Sports Club, 41st & 3rd, New York
# 18  New York Sports Club         New York Sports Club, 76th & 1st, New York
# 19  New York Sports Club       New York Sports Club, Forest Hills, New York
# 20  New York Sports Club       New York Sports Club, Forest Hills, New York
# 21  New York Sports Club      New York Sports Club, Hoboken North, New York
# 22  New York Sports Club          New York Sports Club, Princeton, New York
# 23  New York Sports Club          New York Sports Club, Larchmont, New York
# 24  New York Sports Club  New York Sports Club, White Plains City Center...
# 25  New York Sports Club          New York Sports Club, Bay Ridge, New York
# 26  New York Sports Club             New York Sports Club, Butler, New York
# 27  New York Sports Club        New York Sports Club, Dobbs Ferry, New York
# 28  New York Sports Club         New York Sports Club, 76th & 1st, New York
# 29  New York Sports Club     New York Sports Club, East Brunswick, New York
# 30  New York Sports Club          New York Sports Club, Greenwich, New York
# 31  New York Sports Club         New York Sports Club, Huntington, New York
# 32  New York Sports Club          New York Sports Club, Oceanside, New York
# 33  New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 34  New York Sports Club            New York Sports Club, Hoboken, New York
# 35  New York Sports Club            New York Sports Club, Midwood, New York
# 36  New York Sports Club    New York Sports Club, 63rd & West End, New York
# 37  New York Sports Club            New York Sports Club, Astoria, New York
# 38  New York Sports Club        New York Sports Club, 59th & Park, New York
# 39  New York Sports Club      New York Sports Club, Grand Central, New York
# 40  New York Sports Club         New York Sports Club, Park Slope, New York
# 41  New York Sports Club  New York Sports Club, 145th & Frederick Dougla...
# 42  New York Sports Club  New York Sports Club, 73rd & Central Park West...
# 43  New York Sports Club    New York Sports Club, 80th & Broadway, New York
# 44  New York Sports Club           New York Sports Club, Woodmere, New York
# 45  New York Sports Club         New York Sports Club, 76th & 1st, New York
# 46  New York Sports Club         New York Sports Club, 91st & 3rd, New York
# 47  New York Sports Club         New York Sports Club, Great Neck, New York
# 48  New York Sports Club       New York Sports Club, Irving Place, New York
# 49  New York Sports Club    New York Sports Club, 62nd & Broadway, New York
#
#                       class     day start_time length zip_code price  \
# 0   Total Body Conditioning  Sunday  5:30 p.m.  60min    10128  Paid
# 1                   Cycling  Sunday  5:30 p.m.  45min    10128  Paid
# 2                      Step  Sunday  6:30 p.m.  45min    10128  Paid
# 3                   Cycling  Sunday  6:30 p.m.  45min    10128  Paid
# 4   Total Body Conditioning  Sunday  7:15 p.m.  45min    10128  Paid
# 5                       UXF  Monday  5:00 a.m.  60min    08816  Paid
# 6                       UXF  Monday  5:00 a.m.  60min    11561  Paid
# 7       Functional Training  Monday  5:00 a.m.  60min    10532  Paid
# 8       Functional Training  Monday  5:15 a.m.  60min    11598  Paid
# 9                   Cycling  Monday  5:30 a.m.  45min    11787  Paid
# 10   Cardio Sports Training  Monday  5:30 a.m.  60min    10027  Paid
# 11                  Cycling  Monday  5:30 a.m.  45min    10923  Paid
# 12                  Cycling  Monday  5:45 a.m.  45min    10512  Paid
# 13                     Burn  Monday  5:45 a.m.  45min    07014  Paid
# 14                  Cycling  Monday  5:45 a.m.  45min    07042  Paid
# 15                Boot Camp  Monday  5:45 a.m.  60min    06107  Paid
# 16                  Cycling  Monday  5:45 a.m.  45min    10583  Paid
# 17           Advanced Barre  Monday  6:00 a.m.  60min    10036  Paid
# 18                  Cycling  Monday  6:00 a.m.  45min    10021  Paid
# 19                  Cycling  Monday  6:00 a.m.  45min    11375  Paid
# 20                      UXF  Monday  6:00 a.m.  60min    11375  Paid
# 21                  Cycling  Monday  6:00 a.m.  45min    07030  Paid
# 22                      UXF  Monday  6:00 a.m.  60min    08540  Paid
# 23                  Cycling  Monday  6:00 a.m.  45min    10538  Paid
# 24                  Cycling  Monday  6:00 a.m.  45min    10601  Paid
# 25                  Cycling  Monday  6:00 a.m.  45min    11209  Paid
# 26                  Cycling  Monday  6:00 a.m.  45min    07405  Paid
# 27                  Cycling  Monday  6:00 a.m.  45min    10522  Paid
# 28         Pilates Reformer  Monday  6:00 a.m.  60min    10021  Paid
# 29                     Burn  Monday  6:00 a.m.  60min    08816  Paid
# 30          Step and Sculpt  Monday  6:00 a.m.  60min    06830  Paid
# 31                  Cycling  Monday  6:00 a.m.  45min    11743  Paid
# 32                  Cycling  Monday  6:00 a.m.  45min    11572  Paid
# 33                  Cycling  Monday  6:15 a.m.  45min    10128  Paid
# 34                  Cycling  Monday  6:15 a.m.  45min    07030  Paid
# 35  Total Body Conditioning  Monday  6:15 a.m.  60min    11229  Paid
# 36                      UXF  Monday  6:15 a.m.  60min    10023  Paid
# 37                  Cycling  Monday  6:30 a.m.  45min    11103  Paid
# 38                  Cycling  Monday  6:30 a.m.  45min    10022  Paid
# 39                  Cycling  Monday  6:30 a.m.  45min    10166  Paid
# 40                  Cycling  Monday  6:30 a.m.  45min    11215  Paid
# 41                      UXF  Monday  6:30 a.m.  60min    10039  Paid
# 42                  Cycling  Monday  6:30 a.m.  45min    10023  Paid
# 43                 BODYPUMP  Monday  6:30 a.m.  45min    10024  Paid
# 44                      UXF  Monday  6:30 a.m.  60min    11598  Paid
# 45              Pilates Mat  Monday  6:30 a.m.  45min    10021  Paid
# 46                 BODYPUMP  Monday  6:30 a.m.  60min    10128  Paid
# 47                  Cycling  Monday  6:30 a.m.  45min    11021  Paid
# 48                  Cycling  Monday  6:30 a.m.  45min    10003  Paid
# 49                  Cycling  Monday  6:30 a.m.  45min    10023  Paid
#
#                                                   url
# 0   https://www.newyorksportsclubs.com/join/try/35...
# 1   https://www.newyorksportsclubs.com/join/try/35...
# 2   https://www.newyorksportsclubs.com/join/try/35...
# 3   https://www.newyorksportsclubs.com/join/try/35...
# 4   https://www.newyorksportsclubs.com/join/try/35...
# 5   https://www.newyorksportsclubs.com/join/reserv...
# 6   https://www.newyorksportsclubs.com/join/reserv...
# 7   https://www.newyorksportsclubs.com/join/reserv...
# 8   https://www.newyorksportsclubs.com/join/reserv...
# 9   https://www.newyorksportsclubs.com/join/try/35...
# 10  https://www.newyorksportsclubs.com/join/try/35...
# 11  https://www.newyorksportsclubs.com/join/try/35...
# 12  https://www.newyorksportsclubs.com/join/try/35...
# 13  https://www.newyorksportsclubs.com/join/try/35...
# 14  https://www.newyorksportsclubs.com/join/try/35...
# 15  https://www.newyorksportsclubs.com/join/try/35...
# 16  https://www.newyorksportsclubs.com/join/try/35...
# 17  https://www.newyorksportsclubs.com/join/reserv...
# 18                https://www.newyorksportsclubs.com#
# 19  https://www.newyorksportsclubs.com/join/try/35...
# 20  https://www.newyorksportsclubs.com/join/reserv...
# 21  https://www.newyorksportsclubs.com/join/try/35...
# 22  https://www.newyorksportsclubs.com/join/reserv...
# 23  https://www.newyorksportsclubs.com/join/try/35...
# 24  https://www.newyorksportsclubs.com/join/try/35...
# 25  https://www.newyorksportsclubs.com/join/try/35...
# 26  https://www.newyorksportsclubs.com/join/try/35...
# 27  https://www.newyorksportsclubs.com/join/try/35...
# 28  https://www.newyorksportsclubs.com/join/reserv...
# 29  https://www.newyorksportsclubs.com/join/try/35...
# 30  https://www.newyorksportsclubs.com/join/try/35...
# 31  https://www.newyorksportsclubs.com/join/try/35...
# 32  https://www.newyorksportsclubs.com/join/try/35...
# 33                https://www.newyorksportsclubs.com#
# 34  https://www.newyorksportsclubs.com/join/try/35...
# 35  https://www.newyorksportsclubs.com/join/try/35...
# 36  https://www.newyorksportsclubs.com/join/reserv...
# 37                https://www.newyorksportsclubs.com#
# 38  https://www.newyorksportsclubs.com/join/try/35...
# 39  https://www.newyorksportsclubs.com/join/try/35...
# 40                https://www.newyorksportsclubs.com#
# 41  https://www.newyorksportsclubs.com/join/reserv...
# 42  https://www.newyorksportsclubs.com/join/try/35...
# 43  https://www.newyorksportsclubs.com/join/try/35...
# 44  https://www.newyorksportsclubs.com/join/reserv...
# 45  https://www.newyorksportsclubs.com/join/try/35...
# 46  https://www.newyorksportsclubs.com/join/try/35...
# 47  https://www.newyorksportsclubs.com/join/try/35...
# 48  https://www.newyorksportsclubs.com/join/try/35...
# 49  https://www.newyorksportsclubs.com/join/try/35...

# %%
nysc = nysc[nysc.url != "https://www.newyorksportsclubs.com#"]
nysc.head()
# Out:
#                  center                                     address  \
# 0  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 1  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 2  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 3  New York Sports Club  New York Sports Club, 91st & 3rd, New York
# 4  New York Sports Club  New York Sports Club, 91st & 3rd, New York
#
#                      class     day start_time length zip_code price  \
# 0  Total Body Conditioning  Sunday  5:30 p.m.  60min    10128  Paid
# 1                  Cycling  Sunday  5:30 p.m.  45min    10128  Paid
# 2                     Step  Sunday  6:30 p.m.  45min    10128  Paid
# 3                  Cycling  Sunday  6:30 p.m.  45min    10128  Paid
# 4  Total Body Conditioning  Sunday  7:15 p.m.  45min    10128  Paid
#
#                                                  url
# 0  https://www.newyorksportsclubs.com/join/try/35...
# 1  https://www.newyorksportsclubs.com/join/try/35...
# 2  https://www.newyorksportsclubs.com/join/try/35...
# 3  https://www.newyorksportsclubs.com/join/try/35...
# 4  https://www.newyorksportsclubs.com/join/try/35...

# %%
//nysc completed

# %%
with open("nysc.pk","rb") as f:
    for_al = pickle.load(f)

# %%
for_al.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#           date length         name                room               time
# 0  Sun, Dec 09  60min  91st & 3rd         [@ Studio 1]  5:30 PM - 6:30 PM
# 1  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  5:30 PM - 6:15 PM
# 2  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  6:30 PM - 7:15 PM
# 3  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  6:30 PM - 7:15 PM
# 4  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  7:15 PM - 8:00 PM

# %%
def split_time(time):
    return str(time).split("-")[0].strip()

# %%
for_al['start_time'] = for_al.time.apply(lambda x:str(x).split("-")[0].strip())
for_al['end_time'] = for_al.time.apply(lambda x:str(x).split("-")[1].strip())
for_al.head()
# Out:
#                        Reserve  \
# 0  [/classes/35195586/reserve]
# 1  [/classes/35195589/reserve]
# 2  [/classes/35195584/reserve]
# 3  [/classes/35195591/reserve]
# 4  [/classes/35195585/reserve]
#
#                                                  Try                 activity  \
# 0  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
# 1  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 2  https://www.newyorksportsclubs.com/join/try/35...                     Step
# 3  https://www.newyorksportsclubs.com/join/try/35...                  Cycling
# 4  https://www.newyorksportsclubs.com/join/try/35...  Total Body Conditioning
#
#           date length         name                room               time  \
# 0  Sun, Dec 09  60min  91st & 3rd         [@ Studio 1]  5:30 PM - 6:30 PM
# 1  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  5:30 PM - 6:15 PM
# 2  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  6:30 PM - 7:15 PM
# 3  Sun, Dec 09  45min  91st & 3rd   [@ Cycling Studio]  6:30 PM - 7:15 PM
# 4  Sun, Dec 09  45min  91st & 3rd         [@ Studio 1]  7:15 PM - 8:00 PM
#
#   start_time end_time
# 0    5:30 PM  6:30 PM
# 1    5:30 PM  6:15 PM
# 2    6:30 PM  7:15 PM
# 3    6:30 PM  7:15 PM
# 4    7:15 PM  8:00 PM

# %%
with open("nysc_edited.pk","wb") as f:
    pickle.dump(for_al,f)

# %%
for_al.time.apply(split_time)
# Out:
# 0        5:30 PM
# 1        5:30 PM
# 2        6:30 PM
# 3        6:30 PM
# 4        7:15 PM
# 5        5:00 AM
# 6        5:00 AM
# 7        5:00 AM
# 8        5:15 AM
# 9        5:30 AM
# 10       5:30 AM
# 11       5:30 AM
# 12       5:45 AM
# 13       5:45 AM
# 14       5:45 AM
# 15       5:45 AM
# 16       5:45 AM
# 17       6:00 AM
# 18       6:00 AM
# 19       6:00 AM
# 20       6:00 AM
# 21       6:00 AM
# 22       6:00 AM
# 23       6:00 AM
# 24       6:00 AM
# 25       6:00 AM
# 26       6:00 AM
# 27       6:00 AM
# 28       6:00 AM
# 29       6:00 AM
#           ...
# 10931    1:00 PM
# 10932    1:00 PM
# 10933    1:00 PM
# 10934    1:15 PM
# 10935    1:15 PM
# 10936    1:30 PM
# 10937    1:30 PM
# 10938    1:30 PM
# 10939    1:30 PM
# 10940    1:30 PM
# 10941    1:30 PM
# 10942    2:00 PM
# 10943    2:00 PM
# 10944    2:00 PM
# 10945    2:00 PM
# 10946    2:00 PM
# 10947    2:00 PM
# 10948    2:30 PM
# 10949    3:00 PM
# 10950    3:00 PM
# 10951    3:15 PM
# 10952    4:00 PM
# 10953    4:00 PM
# 10954    4:00 PM
# 10955    5:00 PM
# 10956    5:00 PM
# 10957    5:00 PM
# 10958    5:30 PM
# 10959    6:00 PM
# 10960    6:30 PM
# Name: time, Length: 10961, dtype: object

# %%
cycle.head()
# Out:
#                address        class   date        day    duration instructor  \
# 0  8 West 19th Street    SoulCycle   12-01  Monday 26  45 minutes        Eve
# 1  8 West 19th Street    SoulCycle   12-01  Monday 26  45 minutes       Hugo
# 2  8 West 19th Street    SoulCycle   12-01  Monday 26  45 minutes      Roxie
# 3  8 West 19th Street    SoulCycle   12-01  Monday 26  45 minutes        Eve
# 4  8 West 19th Street    SoulCycle   12-01  Monday 26  45 minutes     Mantas
#
#   location     time                                                url
# 0    10011    7:00A  https://www.soul-cycle.com/find-a-class/studio...
# 1    10011    8:00A  https://www.soul-cycle.com/find-a-class/studio...
# 2    10011   12:30P  https://www.soul-cycle.com/find-a-class/studio...
# 3    10011    5:30P  https://www.soul-cycle.com/find-a-class/studio...
# 4    10011    6:30P  https://www.soul-cycle.com/find-a-class/studio...

# %%
cycle.duration = cycle.duration.apply(lambda x:x.replace(" minutes","min"))
cycle.head()
# Out:
#                address        class   date        day duration instructor  \
# 0  8 West 19th Street    SoulCycle   12-01  Monday 26    45min        Eve
# 1  8 West 19th Street    SoulCycle   12-01  Monday 26    45min       Hugo
# 2  8 West 19th Street    SoulCycle   12-01  Monday 26    45min      Roxie
# 3  8 West 19th Street    SoulCycle   12-01  Monday 26    45min        Eve
# 4  8 West 19th Street    SoulCycle   12-01  Monday 26    45min     Mantas
#
#   location     time                                                url
# 0    10011    7:00A  https://www.soul-cycle.com/find-a-class/studio...
# 1    10011    8:00A  https://www.soul-cycle.com/find-a-class/studio...
# 2    10011   12:30P  https://www.soul-cycle.com/find-a-class/studio...
# 3    10011    5:30P  https://www.soul-cycle.com/find-a-class/studio...
# 4    10011    6:30P  https://www.soul-cycle.com/find-a-class/studio...

# %%
def fmt_time(time):
    if "A" in time:
        return time.replace("A"," a.m.")
    elif "P" in time:
        return time.replace("P"," p.m.")

# %%
cycle.time = cycle.time.apply(fmt_time)
cycle.head()
# Out:
#                address        class   date        day duration instructor  \
# 0  8 West 19th Street    SoulCycle   12-01  Monday 26    45min        Eve
# 1  8 West 19th Street    SoulCycle   12-01  Monday 26    45min       Hugo
# 2  8 West 19th Street    SoulCycle   12-01  Monday 26    45min      Roxie
# 3  8 West 19th Street    SoulCycle   12-01  Monday 26    45min        Eve
# 4  8 West 19th Street    SoulCycle   12-01  Monday 26    45min     Mantas
#
#   location         time                                                url
# 0    10011    7:00 a.m.  https://www.soul-cycle.com/find-a-class/studio...
# 1    10011    8:00 a.m.  https://www.soul-cycle.com/find-a-class/studio...
# 2    10011   12:30 p.m.  https://www.soul-cycle.com/find-a-class/studio...
# 3    10011    5:30 p.m.  https://www.soul-cycle.com/find-a-class/studio...
# 4    10011    6:30 p.m.  https://www.soul-cycle.com/find-a-class/studio...

# %%
cycle["price"] = "Paid"

# %%
cycle.day = cycle.day.apply(lambda x:x.split()[0])

# %%
cycle['center'] = "SoulCycle"
cycle['class'] = "Cycling"
cycle.head()
# Out:
#                address    class   date     day duration instructor location  \
# 0  8 West 19th Street   Cycling  12-01  Monday    45min        Eve    10011
# 1  8 West 19th Street   Cycling  12-01  Monday    45min       Hugo    10011
# 2  8 West 19th Street   Cycling  12-01  Monday    45min      Roxie    10011
# 3  8 West 19th Street   Cycling  12-01  Monday    45min        Eve    10011
# 4  8 West 19th Street   Cycling  12-01  Monday    45min     Mantas    10011
#
#           time                                                url price  \
# 0    7:00 a.m.  https://www.soul-cycle.com/find-a-class/studio...  Paid
# 1    8:00 a.m.  https://www.soul-cycle.com/find-a-class/studio...  Paid
# 2   12:30 p.m.  https://www.soul-cycle.com/find-a-class/studio...  Paid
# 3    5:30 p.m.  https://www.soul-cycle.com/find-a-class/studio...  Paid
# 4    6:30 p.m.  https://www.soul-cycle.com/find-a-class/studio...  Paid
#
#       center
# 0  SoulCycle
# 1  SoulCycle
# 2  SoulCycle
# 3  SoulCycle
# 4  SoulCycle

# %%
cycle = cycle[["center","address","class","day","time","duration","location","price","url"]]
cycle.head()
# Out:
#       center              address    class     day         time duration  \
# 0  SoulCycle  8 West 19th Street   Cycling  Monday    7:00 a.m.    45min
# 1  SoulCycle  8 West 19th Street   Cycling  Monday    8:00 a.m.    45min
# 2  SoulCycle  8 West 19th Street   Cycling  Monday   12:30 p.m.    45min
# 3  SoulCycle  8 West 19th Street   Cycling  Monday    5:30 p.m.    45min
# 4  SoulCycle  8 West 19th Street   Cycling  Monday    6:30 p.m.    45min
#
#   location price                                                url
# 0    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 1    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 2    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 3    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 4    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...

# %%
cycle = cycle.rename(index=str,columns={"time":"start_time","duration":'length',"location":"zip_code"})
cycle.head()
# Out:
#       center              address    class     day   start_time length  \
# 0  SoulCycle  8 West 19th Street   Cycling  Monday    7:00 a.m.  45min
# 1  SoulCycle  8 West 19th Street   Cycling  Monday    8:00 a.m.  45min
# 2  SoulCycle  8 West 19th Street   Cycling  Monday   12:30 p.m.  45min
# 3  SoulCycle  8 West 19th Street   Cycling  Monday    5:30 p.m.  45min
# 4  SoulCycle  8 West 19th Street   Cycling  Monday    6:30 p.m.  45min
#
#   zip_code price                                                url
# 0    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 1    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 2    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 3    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...
# 4    10011  Paid  https://www.soul-cycle.com/find-a-class/studio...

# %%
cycle.address = cycle.address.apply(lambda x: x.strip())

# %%
cycle.shape
# Out:
# (3918, 9)

# %%
cycle = cycle.drop_duplicates()
cycle.shape
# Out:
# (3514, 9)

# %%
//cycle completed

# %%
df = park.append(nysc).append(cycle)
df.head()
# Out:
#                          center                 address  \
# 0     Bronxworks Classic Center   286 East 156th Street
# 1                       P.S. 11          1257 Ogden Ave
# 2              Lincoln Hospital   234 East 149th Street
# 3  St. Mary’s Recreation Center  450 Saint Ann's Avenue
# 4   St. Mary's Community Center         595 Trinity Ave
#
#                             class        day start_time length zip_code price  \
# 0                  Aerobic Dance    Thursday  7:00 p.m.  60min    10451  Free
# 1  Bilingual Belly Dance Fitness   Wednesday  9:00 a.m.  90min    10452  Free
# 2        Bilingual Dance Fitness    Thursday  6:00 p.m.  60min    10451  Free
# 3                Bilingual Zumba    Thursday  7:00 p.m.  60min    10455  Free
# 4                Bilingual Zumba   Wednesday  7:00 p.m.  60min    10455  Free
#
#                                                  url
# 0  https://www.nycgovparks.org/programs/recreatio...
# 1  https://www.nycgovparks.org/programs/recreatio...
# 2  https://www.nycgovparks.org/programs/recreatio...
# 3  https://www.nycgovparks.org/programs/recreatio...
# 4  https://www.nycgovparks.org/programs/recreatio...

# %%
df.shape
# Out:
# (10337, 9)

# %%
df.to_csv("classes.csv",header=False,index=False)

# %%
park_ready = park.drop(columns=['end_time'])
park_ready.to_csv('park.csv',header=False,index=False)

# %%
nysc_dropped = nysc.drop(columns='length')

# %%
def stripped(room):
    if room == []:
        return "N/A"
    return room[0]

# %%
nysc_dropped.room = nysc_dropped.room.apply(stripped)

# %%
nysc_dropped.to_csv('nysc.csv',header = False,index=False)

# %%
with open("soulcycle.pk","rb") as f:
    cycle = pickle.load(f)

# %%
def clean_day(day):
    return day.split()[0]
def clean_time(time):
    if "A" in time:
        return time.replace("A"," A.M.")
    elif "P" in time:
        return time.replace("P"," P.M.")

# %%
cycle.day = cycle.day.apply(clean_day)
cycle.time = cycle.time.apply(clean_time)

# %%
cycle.head()
# Out:
#                address        class   date     day    duration instructor  \
# 0  8 West 19th Street    SoulCycle   12-01  Monday  45 minutes        Eve
# 1  8 West 19th Street    SoulCycle   12-01  Monday  45 minutes       Hugo
# 2  8 West 19th Street    SoulCycle   12-01  Monday  45 minutes      Roxie
# 3  8 West 19th Street    SoulCycle   12-01  Monday  45 minutes        Eve
# 4  8 West 19th Street    SoulCycle   12-01  Monday  45 minutes     Mantas
#
#   location         time                                                url
# 0    10011    7:00 A.M.  https://www.soul-cycle.com/find-a-class/studio...
# 1    10011    8:00 A.M.  https://www.soul-cycle.com/find-a-class/studio...
# 2    10011   12:30 P.M.  https://www.soul-cycle.com/find-a-class/studio...
# 3    10011    5:30 P.M.  https://www.soul-cycle.com/find-a-class/studio...
# 4    10011    6:30 P.M.  https://www.soul-cycle.com/find-a-class/studio...

# %%
cycle_ready = cycle.drop(columns=['date','duration','instructor','location'])
cycle_ready.head()
# Out:
#                address        class     day     time  \
# 0  8 West 19th Street    SoulCycle   Monday    7:00A
# 1  8 West 19th Street    SoulCycle   Monday    8:00A
# 2  8 West 19th Street    SoulCycle   Monday   12:30P
# 3  8 West 19th Street    SoulCycle   Monday    5:30P
# 4  8 West 19th Street    SoulCycle   Monday    6:30P
#
#                                                  url
# 0  https://www.soul-cycle.com/find-a-class/studio...
# 1  https://www.soul-cycle.com/find-a-class/studio...
# 2  https://www.soul-cycle.com/find-a-class/studio...
# 3  https://www.soul-cycle.com/find-a-class/studio...
# 4  https://www.soul-cycle.com/find-a-class/studio...

# %%
cycle_ready.to_csv("cycle.csv",header=False,index=False)
